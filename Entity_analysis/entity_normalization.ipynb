# %%
import os
import json
import pandas as pd
import yaml
import sys  # Import sys to change the field size limit
import csv

#Set working directory
os.chdir('/scratch/sjw6257/KG2_vs_DrugMechDB')

# %%
# Open DrugMechDB YAML file
def load_yaml_file(file_path):
    try:
        with open(file_path, 'r') as file:
            return yaml.safe_load(file)
    except Exception as e:
        print(f"An error occurred: {e}")

drug_db = load_yaml_file('indication_paths.yaml') # Change the pathway where your yaml file is located

# Display YAML file
#drug_db
# Out:
# [{'directed': True,
#   'graph': {'_id': 'DB00619_MESH_D015464_1',
#    'disease': 'CML (ph+)',
#    'disease_mesh': 'MESH:D015464',
#    'drug': 'imatinib',
#    'drug_mesh': 'MESH:D000068877',
#    'drugbank': 'DB:DB00619'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D000068877',
#     'target': 'UniProt:P00519'},
#    {'key': 'causes', 'source': 'UniProt:P00519', 'target': 'MESH:D015464'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D000068877', 'label': 'Drug', 'name': 'imatinib'},
#    {'id': 'UniProt:P00519', 'label': 'Protein', 'name': 'BCR/ABL'},
#    {'id': 'MESH:D015464', 'label': 'Disease', 'name': 'CML (ph+)'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00619_MESH_D034721_1',
#    'disease': 'Systemic mast cell disease',
#    'disease_mesh': 'MESH:D034721',
#    'drug': 'imatinib',
#    'drug_mesh': 'MESH:D000068877',
#    'drugbank': 'DB:DB00619'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D000068877',
#     'target': 'UniProt:P10721'},
#    {'key': 'decreases activity of',
#     'source': 'MESH:D000068877',
#     'target': 'UniProt:P16234'},
#    {'key': 'positively regulates',
#     'source': 'UniProt:P10721',
#     'target': 'GO:0008283'},
#    {'key': 'positively regulates',
#     'source': 'UniProt:P16234',
#     'target': 'GO:0008283'},
#    {'key': 'causes', 'source': 'GO:0008283', 'target': 'MESH:D034721'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D000068877', 'label': 'Drug', 'name': 'imatinib'},
#    {'id': 'UniProt:P10721', 'label': 'Protein', 'name': 'c-Kit'},
#    {'id': 'UniProt:P16234', 'label': 'Protein', 'name': 'Pdgf'},
#    {'id': 'GO:0008283',
#     'label': 'BiologicalProcess',
#     'name': 'Cellular proliferation'},
#    {'id': 'MESH:D034721',
#     'label': 'Disease',
#     'name': 'Systemic mast cell disease'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00316_MESH_D010146_1',
#    'disease': 'Pain',
#    'disease_mesh': 'MESH:D010146',
#    'drug': 'Acetaminophen',
#    'drug_mesh': 'MESH:D000082',
#    'drugbank': 'DB:DB00316'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D000082',
#     'target': 'UniProt:P23219'},
#    {'key': 'decreases activity of',
#     'source': 'MESH:D000082',
#     'target': 'UniProt:P35354'},
#    {'key': 'decreases activity of',
#     'source': 'MESH:D000082',
#     'target': 'UniProt:Q15185'},
#    {'key': 'positively regulates',
#     'source': 'UniProt:P23219',
#     'target': 'GO:0001516'},
#    {'key': 'positively regulates',
#     'source': 'UniProt:P35354',
#     'target': 'GO:0001516'},
#    {'key': 'positively regulates',
#     'source': 'UniProt:Q15185',
#     'target': 'GO:0001516'},
#    {'key': 'increases abundance of',
#     'source': 'GO:0001516',
#     'target': 'MESH:D011453'},
#    {'key': 'positively correlated with',
#     'source': 'MESH:D011453',
#     'target': 'MESH:D010146'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D000082', 'label': 'Drug', 'name': 'Acetaminophen'},
#    {'id': 'UniProt:P23219',
#     'label': 'Protein',
#     'name': 'Prostaglandin G/H synthase 1'},
#    {'id': 'UniProt:P35354',
#     'label': 'Protein',
#     'name': 'Prostaglandin G/H synthase 2'},
#    {'id': 'UniProt:Q15185',
#     'label': 'Protein',
#     'name': 'Prostaglandin E synthase 3'},
#    {'id': 'GO:0001516',
#     'label': 'BiologicalProcess',
#     'name': 'prostaglandin biosynthetic process'},
#    {'id': 'MESH:D011453',
#     'label': 'ChemicalSubstance',
#     'name': 'Prostaglandins'},
#    {'id': 'MESH:D010146', 'label': 'Disease', 'name': 'Pain'}],
#   'reference': ['https://go.drugbank.com/drugs/DB00316#mechanism-of-action',
#    'https://www.uniprot.org/uniprot/P23219#function',
#    'https://www.uniprot.org/uniprot/P35354#function',
#    'https://www.uniprot.org/uniprot/Q15185#function',
#    'https://en.wikipedia.org/wiki/Pain']},
#  {'directed': True,
#   'graph': {'_id': 'DB00316_MESH_D005334_1',
#    'disease': 'Fever',
#    'disease_mesh': 'MESH:D005334',
#    'drug': 'acetaminophen',
#    'drug_mesh': 'MESH:D000082',
#    'drugbank': 'DB:DB00316'},
#   'links': [{'key': 'negatively regulates',
#     'source': 'MESH:D000082',
#     'target': 'reactome:R-HSA-2162123'},
#    {'key': 'occurs in',
#     'source': 'reactome:R-HSA-2162123',
#     'target': 'UBERON:0000955'},
#    {'key': 'location of', 'source': 'UBERON:0000955', 'target': 'GO:0001659'},
#    {'key': 'negatively correlated with',
#     'source': 'GO:0001659',
#     'target': 'MESH:D005334'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D000082', 'label': 'Drug', 'name': 'acetaminophen'},
#    {'id': 'reactome:R-HSA-2162123',
#     'label': 'Pathway',
#     'name': 'cycloxygenaze pathways'},
#    {'id': 'UBERON:0000955',
#     'label': 'GrossAnatomicalStructure',
#     'name': 'Brain'},
#    {'id': 'GO:0001659',
#     'label': 'BiologicalProcess',
#     'name': 'Temperature Homeostasis'},
#    {'id': 'MESH:D005334', 'label': 'Disease', 'name': 'Fever'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00945_MESH_D010146_1',
#    'disease': 'Pain',
#    'disease_mesh': 'MESH:D010146',
#    'drug': 'Aspirin',
#    'drug_mesh': 'MESH:D001241',
#    'drugbank': 'DB:DB00945'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D001241',
#     'target': 'UniProt:P23219'},
#    {'key': 'decreases activity of',
#     'source': 'MESH:D001241',
#     'target': 'UniProt:P35354'},
#    {'key': 'positively regulates',
#     'source': 'UniProt:P23219',
#     'target': 'GO:0001516'},
#    {'key': 'positively regulates',
#     'source': 'UniProt:P35354',
#     'target': 'GO:0001516'},
#    {'key': 'increases abundance of',
#     'source': 'GO:0001516',
#     'target': 'MESH:D011453'},
#    {'key': 'contributes to', 'source': 'MESH:D011453', 'target': 'GO:0006954'},
#    {'key': 'causes', 'source': 'GO:0006954', 'target': 'MESH:D010146'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D001241', 'label': 'Drug', 'name': 'Aspirin'},
#    {'id': 'UniProt:P23219',
#     'label': 'Protein',
#     'name': 'Prostaglandin G/H synthase 1'},
#    {'id': 'UniProt:P35354',
#     'label': 'Protein',
#     'name': 'Prostaglandin G/H synthase 2'},
#    {'id': 'GO:0001516',
#     'label': 'BiologicalProcess',
#     'name': 'prostaglandin biosynthetic process'},
#    {'id': 'MESH:D011453',
#     'label': 'ChemicalSubstance',
#     'name': 'Prostaglandins'},
#    {'id': 'GO:0006954',
#     'label': 'BiologicalProcess',
#     'name': 'inflammatory response'},
#    {'id': 'MESH:D010146', 'label': 'Disease', 'name': 'Pain'}],
#   'reference': ['https://go.drugbank.com/drugs/DB00945#mechanism-of-action',
#    'https://www.uniprot.org/uniprot/P23219#function',
#    'https://www.uniprot.org/uniprot/P35354#function',
#    'https://en.wikipedia.org/wiki/Pain']},
#  {'directed': True,
#   'graph': {'_id': 'DB00945_MESH_D013927_1',
#    'disease': 'Thrombosis',
#    'disease_mesh': 'MESH:D013927',
#    'drug': 'acetylsalicylic acid',
#    'drug_mesh': 'MESH:D001241',
#    'drugbank': 'DB:DB00945'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D001241',
#     'target': 'UniProt:P23219'},
#    {'key': 'participates in',
#     'source': 'UniProt:P23219',
#     'target': 'reactome:R-HSA-2162123'},
#    {'key': 'participates in',
#     'source': 'UniProt:P23219',
#     'target': 'GO:0007596'},
#    {'key': 'has output',
#     'source': 'reactome:R-HSA-2162123',
#     'target': 'MESH:D013928'},
#    {'key': 'participates in',
#     'source': 'MESH:D013928',
#     'target': 'GO:0007596'},
#    {'key': 'causes', 'source': 'GO:0007596', 'target': 'MESH:D013927'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D001241',
#     'label': 'Drug',
#     'name': 'acetylsalicylic acid'},
#    {'id': 'UniProt:P23219', 'label': 'Protein', 'name': 'COX'},
#    {'id': 'reactome:R-HSA-2162123',
#     'label': 'Pathway',
#     'name': 'Synthesis of Prostaglandins and Thromboxanes'},
#    {'id': 'MESH:D013928',
#     'label': 'ChemicalSubstance',
#     'name': 'Thromboxane A2'},
#    {'id': 'GO:0007596',
#     'label': 'BiologicalProcess',
#     'name': 'Platelet Activiation / Blood Coagulation'},
#    {'id': 'MESH:D013927', 'label': 'Disease', 'name': 'Thrombosis'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00788_MESH_D010146_1',
#    'disease': 'Pain',
#    'disease_mesh': 'MESH:D010146',
#    'drug': 'naproxen',
#    'drug_mesh': 'MESH:D009288',
#    'drugbank': 'DB:DB00788'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D009288',
#     'target': 'UniProt:P35354'},
#    {'key': 'increases abundance of',
#     'source': 'UniProt:P35354',
#     'target': 'MESH:D011453'},
#    {'key': 'participates in',
#     'source': 'MESH:D011453',
#     'target': 'GO:0006954'},
#    {'key': 'causes', 'source': 'GO:0006954', 'target': 'MESH:D010146'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D009288', 'label': 'Drug', 'name': 'naproxen'},
#    {'id': 'UniProt:P35354', 'label': 'Protein', 'name': 'Cox-2'},
#    {'id': 'MESH:D011453',
#     'label': 'ChemicalSubstance',
#     'name': 'Prostaglandins'},
#    {'id': 'GO:0006954', 'label': 'BiologicalProcess', 'name': 'Inflammation'},
#    {'id': 'MESH:D010146', 'label': 'Disease', 'name': 'Pain'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB01059_MESH_D004405_1',
#    'disease': 'Shigellosis',
#    'disease_mesh': 'MESH:D004405',
#    'drug': 'norfloxacin',
#    'drug_mesh': 'MESH:D009643',
#    'drugbank': 'DB:DB01059'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D009643',
#     'target': 'UniProt:P43702'},
#    {'key': 'negatively regulates',
#     'source': 'MESH:D009643',
#     'target': 'GO:0003746'},
#    {'key': 'participates in',
#     'source': 'UniProt:P43702',
#     'target': 'GO:0006260'},
#    {'key': 'precedes', 'source': 'GO:0003746', 'target': 'GO:0006412'},
#    {'key': 'occurs in', 'source': 'GO:0006260', 'target': 'taxonomy:622'},
#    {'key': 'occurs in', 'source': 'GO:0006412', 'target': 'taxonomy:622'},
#    {'key': 'causes', 'source': 'taxonomy:622', 'target': 'MESH:D004405'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D009643', 'label': 'Drug', 'name': 'norfloxacin'},
#    {'id': 'UniProt:P43702',
#     'label': 'Protein',
#     'name': 'topoisomerases II, IV'},
#    {'id': 'GO:0003746',
#     'label': 'MolecularActivity',
#     'name': 'Translocation of EF-G'},
#    {'id': 'GO:0006260',
#     'label': 'BiologicalProcess',
#     'name': 'Bacterial DNA replication'},
#    {'id': 'GO:0006412',
#     'label': 'BiologicalProcess',
#     'name': 'Bacterial Protein Synthesis'},
#    {'id': 'taxonomy:622',
#     'label': 'OrganismTaxon',
#     'name': 'Shigella dysenteriae'},
#    {'id': 'MESH:D004405', 'label': 'Disease', 'name': 'Shigellosis'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB01380_MESH_D007634_1',
#    'disease': 'Keratitis',
#    'disease_mesh': 'MESH:D007634',
#    'drug': 'cortisone acetate',
#    'drug_mesh': 'MESH:D003348',
#    'drugbank': 'DB:DB01380'},
#   'links': [{'key': 'increases activity of',
#     'source': 'MESH:D003348',
#     'target': 'UniProt:P04150'},
#    {'key': 'increases abundance of',
#     'source': 'MESH:D003348',
#     'target': 'UniProt:P04083'},
#    {'key': 'decreases abundance of',
#     'source': 'MESH:D003348',
#     'target': 'UniProt:P23219'},
#    {'key': 'increases abundance of',
#     'source': 'UniProt:P04150',
#     'target': 'UniProt:P04083'},
#    {'key': 'decreases abundance of',
#     'source': 'UniProt:P04150',
#     'target': 'UniProt:P23219'},
#    {'key': 'increases abundance of',
#     'source': 'UniProt:P23219',
#     'target': 'MESH:D011453'},
#    {'key': 'negatively regulates',
#     'source': 'UniProt:P04083',
#     'target': 'GO:0050900'},
#    {'key': 'negatively regulates',
#     'source': 'UniProt:P04083',
#     'target': 'reactome:R-HSA-2162123'},
#    {'key': 'participates in',
#     'source': 'reactome:R-HSA-2162123',
#     'target': 'GO:0006954'},
#    {'key': 'participates in',
#     'source': 'MESH:D011453',
#     'target': 'GO:0006954'},
#    {'key': 'positively regulates',
#     'source': 'GO:0050900',
#     'target': 'GO:0006954'},
#    {'key': 'positively regulates',
#     'source': 'reactome:R-HSA-2162123',
#     'target': 'GO:0006954'},
#    {'key': 'causes', 'source': 'GO:0006954', 'target': 'MESH:D007634'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D003348',
#     'label': 'Drug',
#     'name': 'cortisone acetate'},
#    {'id': 'UniProt:P04150',
#     'label': 'Protein',
#     'name': 'Glucocorticoid receptor'},
#    {'id': 'UniProt:P23219', 'label': 'Protein', 'name': 'COX Genes'},
#    {'id': 'UniProt:P04083', 'label': 'Protein', 'name': 'lipocortin-1'},
#    {'id': 'reactome:R-HSA-2162123',
#     'label': 'Pathway',
#     'name': 'Prostaglandin Synthesis'},
#    {'id': 'MESH:D011453',
#     'label': 'ChemicalSubstance',
#     'name': 'Prostaglandins'},
#    {'id': 'GO:0050900',
#     'label': 'BiologicalProcess',
#     'name': 'Immune Cell Funciton'},
#    {'id': 'GO:0006954', 'label': 'BiologicalProcess', 'name': 'Inflammation'},
#    {'id': 'MESH:D007634', 'label': 'Disease', 'name': 'Keratitis'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB01610_MESH_D003586_1',
#    'disease': 'CMV infection',
#    'disease_mesh': 'MESH:D003586',
#    'drug': 'valganciclovir',
#    'drug_mesh': 'MESH:D000077562',
#    'drugbank': 'DB:DB01610'},
#   'links': [{'key': 'increases abundance of',
#     'source': 'MESH:D000077562',
#     'target': 'MESH:D015774'},
#    {'key': 'negatively regulates',
#     'source': 'MESH:D015774',
#     'target': 'GO:0039693'},
#    {'key': 'occurs in', 'source': 'GO:0039693', 'target': 'taxonomy:10358'},
#    {'key': 'causes', 'source': 'taxonomy:10358', 'target': 'MESH:D003586'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D000077562',
#     'label': 'Drug',
#     'name': 'valganciclovir'},
#    {'id': 'MESH:D015774', 'label': 'ChemicalSubstance', 'name': 'ganciclovir'},
#    {'id': 'GO:0039693',
#     'label': 'BiologicalProcess',
#     'name': 'viral DNA replication'},
#    {'id': 'taxonomy:10358',
#     'label': 'OrganismTaxon',
#     'name': 'Cytomegalovirus'},
#    {'id': 'MESH:D003586', 'label': 'Disease', 'name': 'CMV infection'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00916_MESH_D018805_1',
#    'disease': 'Bacterial septicemia',
#    'disease_mesh': 'MESH:D018805',
#    'drug': 'metronidazole',
#    'drug_mesh': 'MESH:D008795',
#    'drugbank': 'DB:DB00916'},
#   'links': [{'key': 'increases abundance of',
#     'source': 'MESH:D008795',
#     'target': 'MESH:C029371'},
#    {'key': 'negatively regulates',
#     'source': 'MESH:C029371',
#     'target': 'GO:0003676'},
#    {'key': 'occurs in', 'source': 'GO:0003676', 'target': 'taxonomy:2'},
#    {'key': 'causes', 'source': 'taxonomy:2', 'target': 'MESH:D018805'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D008795', 'label': 'Drug', 'name': 'metronidazole'},
#    {'id': 'MESH:C029371',
#     'label': 'ChemicalSubstance',
#     'name': 'hydroxyethyl oxamic acid'},
#    {'id': 'GO:0003676',
#     'label': 'BiologicalProcess',
#     'name': 'bacterial Nucleic Acid synthesis'},
#    {'id': 'taxonomy:2', 'label': 'OrganismTaxon', 'name': 'Bacteria'},
#    {'id': 'MESH:D018805',
#     'label': 'Disease',
#     'name': 'Bacterial septicemia'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00618_MESH_D000073605_1',
#    'disease': 'Rickettsialpox',
#    'disease_mesh': 'MESH:D000073605',
#    'drug': 'demeclocycline',
#    'drug_mesh': 'MESH:D003707',
#    'drugbank': 'DB:DB00618'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D003707',
#     'target': 'UniProt:P0A7S3'},
#    {'key': 'decreases activity of',
#     'source': 'MESH:D003707',
#     'target': 'UniProt:P0A7J3'},
#    {'key': 'participates in',
#     'source': 'UniProt:P0A7S3',
#     'target': 'GO:0006412'},
#    {'key': 'participates in',
#     'source': 'UniProt:P0A7J3',
#     'target': 'GO:0006412'},
#    {'key': 'occurs in', 'source': 'GO:0006412', 'target': 'taxonomy:786'},
#    {'key': 'causes', 'source': 'taxonomy:786', 'target': 'MESH:D000073605'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D003707', 'label': 'Drug', 'name': 'demeclocycline'},
#    {'id': 'UniProt:P0A7S3',
#     'label': 'Protein',
#     'name': '30S Ribosomal Subunit'},
#    {'id': 'UniProt:P0A7J3',
#     'label': 'Protein',
#     'name': '50S Ribosomal Subunit'},
#    {'id': 'GO:0006412',
#     'label': 'BiologicalProcess',
#     'name': 'Bacterial Translation'},
#    {'id': 'taxonomy:786',
#     'label': 'OrganismTaxon',
#     'name': 'Rickettsia akari'},
#    {'id': 'MESH:D000073605', 'label': 'Disease', 'name': 'Rickettsialpox'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB01060_MESH_D014069_1',
#    'disease': 'Streptococcal tonsillitis',
#    'disease_mesh': 'MESH:D014069',
#    'drug': 'amoxicillin',
#    'drug_mesh': 'MESH:D000658',
#    'drugbank': 'DB:DB01060'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D000658',
#     'target': 'TIGR:02074'},
#    {'key': 'participates in', 'source': 'TIGR:02074', 'target': 'GO:0009252'},
#    {'key': 'occurs in', 'source': 'GO:0009252', 'target': 'taxonomy:1314'},
#    {'key': 'causes', 'source': 'taxonomy:1314', 'target': 'MESH:D014069'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D000658', 'label': 'Drug', 'name': 'amoxicillin'},
#    {'id': 'TIGR:02074',
#     'label': 'GeneFamily',
#     'name': 'Penicillin-binding proteins 1A'},
#    {'id': 'GO:0009252',
#     'label': 'BiologicalProcess',
#     'name': 'Peptidoglycan Biosyntheic Process'},
#    {'id': 'taxonomy:1314',
#     'label': 'OrganismTaxon',
#     'name': 'Streptococcus pyogenes'},
#    {'id': 'MESH:D014069',
#     'label': 'Disease',
#     'name': 'Streptococcal tonsillitis'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB09335_MESH_D011023_1',
#    'disease': 'Staphylococcal pneumonia',
#    'disease_mesh': 'MESH:D011023',
#    'drug': 'alatrofloxacin',
#    'drug_mesh': 'MESH:C106856',
#    'drugbank': 'DB:DB09335'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:C106856',
#     'target': 'UniProt:P0C1U9'},
#    {'key': 'decreases activity of',
#     'source': 'MESH:C106856',
#     'target': 'UniProt:P20831'},
#    {'key': 'participates in',
#     'source': 'UniProt:P0C1U9',
#     'target': 'GO:0006260'},
#    {'key': 'participates in',
#     'source': 'UniProt:P20831',
#     'target': 'GO:0006260'},
#    {'key': 'occurs in', 'source': 'GO:0006260', 'target': 'taxonomy:1280'},
#    {'key': 'causes', 'source': 'taxonomy:1280', 'target': 'MESH:D011023'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:C106856', 'label': 'Drug', 'name': 'alatrofloxacin'},
#    {'id': 'UniProt:P0C1U9', 'label': 'Protein', 'name': 'Topoisomeraze 4'},
#    {'id': 'UniProt:P20831', 'label': 'Protein', 'name': 'DNA gyrase'},
#    {'id': 'GO:0006260',
#     'label': 'BiologicalProcess',
#     'name': 'Bacterial DNA replication'},
#    {'id': 'taxonomy:1280',
#     'label': 'OrganismTaxon',
#     'name': 'Staphylococcus aureus'},
#    {'id': 'MESH:D011023',
#     'label': 'Disease',
#     'name': 'Staphylococcal pneumonia'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00479_MESH_D016920_1',
#    'disease': 'Bacterial meningitis',
#    'disease_mesh': 'MESH:D016920',
#    'drug': 'amikacin',
#    'drug_mesh': 'MESH:D000583',
#    'drugbank': 'DB:DB00479'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D000583',
#     'target': 'UniProt:P0A7S3'},
#    {'key': 'participates in',
#     'source': 'UniProt:P0A7S3',
#     'target': 'GO:0006412'},
#    {'key': 'occurs in', 'source': 'GO:0006412', 'target': 'taxonomy:2'},
#    {'key': 'causes', 'source': 'taxonomy:2', 'target': 'MESH:D016920'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D000583', 'label': 'Drug', 'name': 'amikacin'},
#    {'id': 'UniProt:P0A7S3',
#     'label': 'Protein',
#     'name': '30S Ribosomal Subunit'},
#    {'id': 'GO:0006412',
#     'label': 'BiologicalProcess',
#     'name': 'Bacterial Translation'},
#    {'id': 'taxonomy:2', 'label': 'OrganismTaxon', 'name': 'Bacteria'},
#    {'id': 'MESH:D016920',
#     'label': 'Disease',
#     'name': 'Bacterial meningitis'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB01234_MESH_D013717_1',
#    'disease': 'Tenosynovitis',
#    'disease_mesh': 'MESH:D013717',
#    'drug': 'dexamethasone',
#    'drug_mesh': 'MESH:D003907',
#    'drugbank': 'DB:DB01234'},
#   'links': [{'key': 'increases activity of',
#     'source': 'MESH:D003907',
#     'target': 'UniProt:P04150'},
#    {'key': 'increases abundance of',
#     'source': 'UniProt:P04150',
#     'target': 'UniProt:P04083'},
#    {'key': 'negatively regulates',
#     'source': 'UniProt:P04083',
#     'target': 'reactome:R-HSA-2162123'},
#    {'key': 'positively regulates',
#     'source': 'reactome:R-HSA-2162123',
#     'target': 'GO:0006954'},
#    {'key': 'causes', 'source': 'GO:0006954', 'target': 'MESH:D013717'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D003907', 'label': 'Drug', 'name': 'dexamethasone'},
#    {'id': 'UniProt:P04150',
#     'label': 'Protein',
#     'name': 'Glucocorticoid receptor'},
#    {'id': 'UniProt:P04083', 'label': 'Protein', 'name': 'Annexin A1'},
#    {'id': 'reactome:R-HSA-2162123',
#     'label': 'Pathway',
#     'name': 'Prostaglandin Synthesis'},
#    {'id': 'GO:0006954', 'label': 'BiologicalProcess', 'name': 'Inflammation'},
#    {'id': 'MESH:D013717', 'label': 'Disease', 'name': 'Tenosynovitis'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00438_MESH_D014552_1',
#    'disease': 'Bacterial urinary infection',
#    'disease_mesh': 'MESH:D014552',
#    'drug': 'ceftazidime',
#    'drug_mesh': 'MESH:D002442',
#    'drugbank': 'DB:DB00438'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D002442',
#     'target': 'TIGR:02074'},
#    {'key': 'participates in', 'source': 'TIGR:02074', 'target': 'GO:0009252'},
#    {'key': 'occurs in', 'source': 'GO:0009252', 'target': 'taxonomy:562'},
#    {'key': 'causes', 'source': 'taxonomy:562', 'target': 'MESH:D014552'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D002442', 'label': 'Drug', 'name': 'ceftazidime'},
#    {'id': 'TIGR:02074',
#     'label': 'GeneFamily',
#     'name': 'Penicillin-binding protein 1A'},
#    {'id': 'GO:0009252',
#     'label': 'BiologicalProcess',
#     'name': 'Bacterial Cell Wall Synthesis'},
#    {'id': 'taxonomy:562',
#     'label': 'OrganismTaxon',
#     'name': 'Escherichia coli'},
#    {'id': 'MESH:D014552',
#     'label': 'Disease',
#     'name': 'Bacterial urinary infection'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB06762_MESH_D006973_1',
#    'disease': 'Hypertension',
#    'disease_mesh': 'MESH:D006973',
#    'drug': 'pinacidil',
#    'drug_mesh': 'MESH:D020110',
#    'drugbank': 'DB:DB06762'},
#   'links': [{'key': 'increases activity of',
#     'source': 'MESH:D020110',
#     'target': 'UniProt:Q12791'},
#    {'key': 'participates in',
#     'source': 'UniProt:Q12791',
#     'target': 'GO:0042311'},
#    {'key': 'capable of', 'source': 'GO:0042311', 'target': 'GO:0008217'},
#    {'key': 'prevents', 'source': 'GO:0008217', 'target': 'MESH:D006973'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D020110', 'label': 'Drug', 'name': 'pinacidil'},
#    {'id': 'UniProt:Q12791',
#     'label': 'Protein',
#     'name': 'Calcium-activated potassium channel subunit alpha-1'},
#    {'id': 'GO:0042311', 'label': 'BiologicalProcess', 'name': 'Vasodilation'},
#    {'id': 'GO:0008217',
#     'label': 'BiologicalProcess',
#     'name': 'Negative Regulation of Blood Pressure'},
#    {'id': 'MESH:D006973', 'label': 'Disease', 'name': 'Hypertension'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB01263_MESH_D009181_1',
#    'disease': 'Fungal Infection',
#    'disease_mesh': 'MESH:D009181',
#    'drug': 'posaconazole',
#    'drug_mesh': 'MESH:C101425',
#    'drugbank': 'DB:DB01263'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:C101425',
#     'target': 'UniProt:P10613'},
#    {'key': 'produces', 'source': 'UniProt:P10613', 'target': 'MESH:D004875'},
#    {'key': 'located in', 'source': 'MESH:D004875', 'target': 'GO:0009277'},
#    {'key': 'correlated with',
#     'source': 'GO:0009277',
#     'target': 'MESH:D009181'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:C101425', 'label': 'Drug', 'name': 'posaconazole'},
#    {'id': 'UniProt:P10613',
#     'label': 'Protein',
#     'name': 'sterol 14a-demethylase'},
#    {'id': 'MESH:D004875', 'label': 'ChemicalSubstance', 'name': 'ergosterol'},
#    {'id': 'GO:0009277',
#     'label': 'CellularComponent',
#     'name': 'Fungal Cell Membrane'},
#    {'id': 'MESH:D009181', 'label': 'Disease', 'name': 'Fungal Infection'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB08799_MESH_D012223_1',
#    'disease': 'Vasomotor rhinitis',
#    'disease_mesh': 'MESH:D012223',
#    'drug': 'antazoline',
#    'drug_mesh': 'MESH:D000865',
#    'drugbank': 'DB:DB08799'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D000865',
#     'target': 'UniProt:P35367'},
#    {'key': 'participates in',
#     'source': 'UniProt:P35367',
#     'target': 'GO:0034776'},
#    {'key': 'causes', 'source': 'GO:0034776', 'target': 'MESH:D012223'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D000865', 'label': 'Drug', 'name': 'antazoline'},
#    {'id': 'UniProt:P35367',
#     'label': 'Protein',
#     'name': 'histamine H1 Receptor'},
#    {'id': 'GO:0034776',
#     'label': 'BiologicalProcess',
#     'name': 'histamine response'},
#    {'id': 'MESH:D012223', 'label': 'Disease', 'name': 'Vasomotor rhinitis'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB01137_MESH_D011704_1',
#    'disease': 'Pyelonephritis',
#    'disease_mesh': 'MESH:D011704',
#    'drug': 'levofloxacin',
#    'drug_mesh': 'MESH:D064704',
#    'drugbank': 'DB:DB01137'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D064704',
#     'target': 'UniProt:P11388'},
#    {'key': 'participates in',
#     'source': 'UniProt:P11388',
#     'target': 'GO:0006260'},
#    {'key': 'occurs in', 'source': 'GO:0006260', 'target': 'taxonomy:562'},
#    {'key': 'causes', 'source': 'taxonomy:562', 'target': 'MESH:D011704'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D064704', 'label': 'Drug', 'name': 'levofloxacin'},
#    {'id': 'UniProt:P11388', 'label': 'Protein', 'name': 'DNA gyrase'},
#    {'id': 'GO:0006260',
#     'label': 'BiologicalProcess',
#     'name': 'Bacterial DNA replication'},
#    {'id': 'taxonomy:562', 'label': 'OrganismTaxon', 'name': 'E. coli'},
#    {'id': 'MESH:D011704', 'label': 'Disease', 'name': 'Pyelonephritis'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00814_MESH_D010146_1',
#    'disease': 'Pain',
#    'disease_mesh': 'MESH:D010146',
#    'drug': 'meloxicam',
#    'drug_mesh': 'MESH:D000077239',
#    'drugbank': 'DB:DB00814'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D000077239',
#     'target': 'UniProt:P35354'},
#    {'key': 'increases abundance of',
#     'source': 'UniProt:P35354',
#     'target': 'MESH:D011453'},
#    {'key': 'increases activity of',
#     'source': 'MESH:D011453',
#     'target': 'InterPro:IPR000265'},
#    {'key': 'causes',
#     'source': 'InterPro:IPR000265',
#     'target': 'MESH:D010146'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D000077239', 'label': 'Drug', 'name': 'meloxicam'},
#    {'id': 'UniProt:P35354',
#     'label': 'Protein',
#     'name': 'Prostaglandin synthhase 2'},
#    {'id': 'MESH:D011453',
#     'label': 'ChemicalSubstance',
#     'name': 'Prostaglandins'},
#    {'id': 'InterPro:IPR000265',
#     'label': 'GeneFamily',
#     'name': 'Pain Receptors'},
#    {'id': 'MESH:D010146', 'label': 'Disease', 'name': 'Pain'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00393_MESH_D013345_1',
#    'disease': 'Subarachnoid intracranial hemorrhage',
#    'disease_mesh': 'MESH:D013345',
#    'drug': 'nimodipine',
#    'drug_mesh': 'MESH:D009553',
#    'drugbank': 'DB:DB00393'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D009553',
#     'target': 'InterPro:IPR005446'},
#    {'key': 'positively regulates',
#     'source': 'InterPro:IPR005446',
#     'target': 'GO:0006939'},
#    {'key': 'positively regulates',
#     'source': 'GO:0006939',
#     'target': 'GO:0008217'},
#    {'key': 'positively correlated with',
#     'source': 'GO:0008217',
#     'target': 'MESH:D013345'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D009553', 'label': 'Drug', 'name': 'nimodipine'},
#    {'id': 'InterPro:IPR005446',
#     'label': 'GeneFamily',
#     'name': 'voltage dependent l-type calcium channels'},
#    {'id': 'GO:0006939',
#     'label': 'BiologicalProcess',
#     'name': 'Smooth muscle contraction'},
#    {'id': 'GO:0008217',
#     'label': 'BiologicalProcess',
#     'name': 'Blood Pressure'},
#    {'id': 'MESH:D013345',
#     'label': 'Disease',
#     'name': 'Subarachnoid intracranial hemorrhage'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00326_MESH_D006996_1',
#    'disease': 'hypocalcemia',
#    'disease_mesh': 'MESH:D006996',
#    'drug': 'calcium glucoheptonate',
#    'drug_mesh': 'MESH:C007852',
#    'drugbank': 'DB:DB00326'},
#   'links': [{'key': 'increases abundance of',
#     'source': 'MESH:C007852',
#     'target': 'MESH:D002118'},
#    {'key': 'prevents', 'source': 'MESH:D002118', 'target': 'MESH:D006996'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:C007852',
#     'label': 'Drug',
#     'name': 'calcium glucoheptonate'},
#    {'id': 'MESH:D002118', 'label': 'ChemicalSubstance', 'name': 'Calcium Ion'},
#    {'id': 'MESH:D006996', 'label': 'Disease', 'name': 'hypocalcemia'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00588_MESH_D001991_1',
#    'disease': 'Bronchitis',
#    'disease_mesh': 'MESH:D001991',
#    'drug': 'fluticasone propionate',
#    'drug_mesh': 'MESH:D000068298',
#    'drugbank': 'DB:DB00588'},
#   'links': [{'key': 'increases activity of',
#     'source': 'MESH:D000068298',
#     'target': 'UniProt:P04150'},
#    {'key': 'decreases abundance of',
#     'source': 'UniProt:P04150',
#     'target': 'UniProt:P47712'},
#    {'key': 'increases abundance of',
#     'source': 'UniProt:P04150',
#     'target': 'UniProt:P22301'},
#    {'key': 'positively regulates',
#     'source': 'UniProt:P47712',
#     'target': 'GO:0006954'},
#    {'key': 'negatively regulates',
#     'source': 'UniProt:P22301',
#     'target': 'GO:0006954'},
#    {'key': 'causes', 'source': 'GO:0006954', 'target': 'MESH:D001991'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D000068298',
#     'label': 'Drug',
#     'name': 'fluticasone propionate'},
#    {'id': 'UniProt:P04150',
#     'label': 'Protein',
#     'name': 'Glucocorticoid receptor'},
#    {'id': 'UniProt:P47712', 'label': 'Protein', 'name': 'Phospholipase A2'},
#    {'id': 'UniProt:P22301', 'label': 'Protein', 'name': 'IL-10'},
#    {'id': 'GO:0006954', 'label': 'BiologicalProcess', 'name': 'Inflammation'},
#    {'id': 'MESH:D001991', 'label': 'Disease', 'name': 'Bronchitis'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00623_MESH_D012559_1',
#    'disease': 'Schizophrenia',
#    'disease_mesh': 'MESH:D012559',
#    'drug': 'fluphenazine',
#    'drug_mesh': 'MESH:D005476',
#    'drugbank': 'DB:DB00623'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D005476',
#     'target': 'UniProt:P14416'},
#    {'key': 'decreases activity of',
#     'source': 'MESH:D005476',
#     'target': 'UniProt:P21728'},
#    {'key': 'positively regulates',
#     'source': 'UniProt:P14416',
#     'target': 'GO:0030252'},
#    {'key': 'increases abundance of',
#     'source': 'UniProt:P21728',
#     'target': 'MESH:D010907'},
#    {'key': 'positively correlated with',
#     'source': 'GO:0030252',
#     'target': 'MESH:D012559'},
#    {'key': 'manifestation of',
#     'source': 'MESH:D010907',
#     'target': 'MESH:D012559'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D005476', 'label': 'Drug', 'name': 'fluphenazine'},
#    {'id': 'UniProt:P14416',
#     'label': 'Protein',
#     'name': 'D(2) dopamine receptor'},
#    {'id': 'UniProt:P21728',
#     'label': 'Protein',
#     'name': 'dopaminaergeinc receptors'},
#    {'id': 'GO:0030252',
#     'label': 'BiologicalProcess',
#     'name': 'growth hormone secretion'},
#    {'id': 'MESH:D010907',
#     'label': 'ChemicalSubstance',
#     'name': 'hypophyseal hormones'},
#    {'id': 'MESH:D012559', 'label': 'Disease', 'name': 'Schizophrenia'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00342_MESH_D017449_1',
#    'disease': 'allergic skin disorders',
#    'disease_mesh': 'MESH:D017449',
#    'drug': 'terfenadine',
#    'drug_mesh': 'MESH:D016593',
#    'drugbank': 'DB:DB00342'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D016593',
#     'target': 'UniProt:P35367'},
#    {'key': 'has phenotype',
#     'source': 'UniProt:P35367',
#     'target': 'HP:0000969'},
#    {'key': 'manifestation of',
#     'source': 'HP:0000969',
#     'target': 'MESH:D017449'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D016593', 'label': 'Drug', 'name': 'terfenadine'},
#    {'id': 'UniProt:P35367',
#     'label': 'Protein',
#     'name': 'histamine H1 Receptor'},
#    {'id': 'HP:0000969', 'label': 'PhenotypicFeature', 'name': 'Edema'},
#    {'id': 'MESH:D017449',
#     'label': 'Disease',
#     'name': 'allergic skin disorders'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB01048_MESH_D015658_1',
#    'disease': 'HIV infection',
#    'disease_mesh': 'MESH:D015658',
#    'drug': 'abacavir',
#    'drug_mesh': 'MESH:C106538',
#    'drugbank': 'DB:DB01048'},
#   'links': [{'key': 'increases abundance of',
#     'source': 'MESH:C106538',
#     'target': 'MESH:C066928'},
#    {'key': 'decreases activity of',
#     'source': 'MESH:C066928',
#     'target': 'UniProt:P04585'},
#    {'key': 'participates in',
#     'source': 'UniProt:P04585',
#     'target': 'GO:0039693'},
#    {'key': 'causes', 'source': 'GO:0039693', 'target': 'MESH:D015658'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:C106538', 'label': 'Drug', 'name': 'abacavir'},
#    {'id': 'MESH:C066928',
#     'label': 'ChemicalSubstance',
#     'name': 'carbovir triphosphate'},
#    {'id': 'UniProt:P04585',
#     'label': 'Protein',
#     'name': 'HIV-1 reverse transcriptase'},
#    {'id': 'GO:0039693',
#     'label': 'BiologicalProcess',
#     'name': 'Viral DNA replication'},
#    {'id': 'MESH:D015658', 'label': 'Disease', 'name': 'HIV infection'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00717_MESH_D008595_1',
#    'disease': 'Menorrhagia',
#    'disease_mesh': 'MESH:D008595',
#    'drug': 'norethisterone',
#    'drug_mesh': 'MESH:D009640',
#    'drugbank': 'DB:DB00717'},
#   'links': [{'key': 'increases activity of',
#     'source': 'MESH:D009640',
#     'target': 'UniProt:P06401'},
#    {'key': 'decreases abundance of',
#     'source': 'UniProt:P06401',
#     'target': 'UniProt:P01148'},
#    {'key': 'negatively regulates',
#     'source': 'UniProt:P01148',
#     'target': 'GO:0032275'},
#    {'key': 'correlated with',
#     'source': 'GO:0032275',
#     'target': 'MESH:D008595'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D009640', 'label': 'Drug', 'name': 'norethisterone'},
#    {'id': 'UniProt:P06401',
#     'label': 'Protein',
#     'name': 'progesterone receptor'},
#    {'id': 'UniProt:P01148',
#     'label': 'Protein',
#     'name': 'gonadotropin releasing hormone'},
#    {'id': 'GO:0032275',
#     'label': 'BiologicalProcess',
#     'name': 'Luteinizing hormone secretion'},
#    {'id': 'MESH:D008595', 'label': 'Disease', 'name': 'Menorrhagia'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00246_MESH_D012559_1',
#    'disease': 'Schizophrenia',
#    'disease_mesh': 'MESH:D012559',
#    'drug': 'ziprasidone',
#    'drug_mesh': 'MESH:C092292',
#    'drugbank': 'DB:DB00246'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:C092292',
#     'target': 'UniProt:P14416'},
#    {'key': 'decreases activity of',
#     'source': 'MESH:C092292',
#     'target': 'UniProt:P28223'},
#    {'key': 'participates in',
#     'source': 'UniProt:P14416',
#     'target': 'GO:0061527'},
#    {'key': 'participates in',
#     'source': 'UniProt:P28223',
#     'target': 'GO:0060096'},
#    {'key': 'positively regulates',
#     'source': 'GO:0061527',
#     'target': 'HP:0000738'},
#    {'key': 'positively correlated with',
#     'source': 'GO:0060096',
#     'target': 'MESH:D012701'},
#    {'key': 'manifestation of',
#     'source': 'HP:0000738',
#     'target': 'MESH:D012559'},
#    {'key': 'positively correlated with',
#     'source': 'MESH:D012701',
#     'target': 'MESH:D012559'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:C092292', 'label': 'Drug', 'name': 'ziprasidone'},
#    {'id': 'UniProt:P14416',
#     'label': 'Protein',
#     'name': 'D(2) dopamine receptor'},
#    {'id': 'UniProt:P28223',
#     'label': 'Protein',
#     'name': '5-hydroxytryptamine receptor 2A'},
#    {'id': 'GO:0061527',
#     'label': 'BiologicalProcess',
#     'name': 'dopamine secretion, neurotransmission'},
#    {'id': 'GO:0060096',
#     'label': 'BiologicalProcess',
#     'name': 'serotonin secretion, neurotransmission'},
#    {'id': 'HP:0000738',
#     'label': 'PhenotypicFeature',
#     'name': 'Hallucinations'},
#    {'id': 'MESH:D012701', 'label': 'ChemicalSubstance', 'name': 'Serotonin'},
#    {'id': 'MESH:D012559', 'label': 'Disease', 'name': 'Schizophrenia'}],
#   'reference': ['https://go.drugbank.com/drugs/DB00246#mechanism-of-action',
#    'https://en.wikipedia.org/wiki/Ziprasidone',
#    'https://www.uniprot.org/uniprot/P14416#function',
#    'https://www.uniprot.org/uniprot/P28223#function',
#    'https://en.wikipedia.org/wiki/Schizophrenia']},
#  {'directed': True,
#   'graph': {'_id': 'DB00748_MESH_D003233_1',
#    'disease': 'seasonal allergic conjunctivitis',
#    'disease_mesh': 'MESH:D003233',
#    'drug': 'carbinoxamine',
#    'drug_mesh': 'MESH:C004649',
#    'drugbank': 'DB:DB00748'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:C004649',
#     'target': 'UniProt:P35367'},
#    {'key': 'positively regulates',
#     'source': 'UniProt:P35367',
#     'target': 'GO:0034776'},
#    {'key': 'causes', 'source': 'GO:0034776', 'target': 'MESH:D003233'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:C004649', 'label': 'Drug', 'name': 'carbinoxamine'},
#    {'id': 'UniProt:P35367',
#     'label': 'Protein',
#     'name': 'histamine H1 Receptor'},
#    {'id': 'GO:0034776',
#     'label': 'BiologicalProcess',
#     'name': 'histamine response'},
#    {'id': 'MESH:D003233',
#     'label': 'Disease',
#     'name': 'seasonal allergic conjunctivitis'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00066_MESH_D016649_1',
#    'disease': 'primary ovarian failure',
#    'disease_mesh': 'MESH:D016649',
#    'drug': 'follitropin',
#    'drug_mesh': 'MESH:D005640',
#    'drugbank': 'DB:DB00066'},
#   'links': [{'key': 'increases activity of',
#     'source': 'MESH:D005640',
#     'target': 'UniProt:P23945'},
#    {'key': 'positively regulates',
#     'source': 'UniProt:P23945',
#     'target': 'GO:0030728'},
#    {'key': 'negatively correlated with',
#     'source': 'GO:0030728',
#     'target': 'MESH:D016649'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D005640', 'label': 'Drug', 'name': 'follitropin'},
#    {'id': 'UniProt:P23945',
#     'label': 'Protein',
#     'name': 'Human follicle stimulating hormone receptor'},
#    {'id': 'GO:0030728', 'label': 'BiologicalProcess', 'name': 'ovulation'},
#    {'id': 'MESH:D016649',
#     'label': 'Disease',
#     'name': 'primary ovarian failure'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB01212_MESH_D006069_1',
#    'disease': 'Gonorrhea',
#    'disease_mesh': 'MESH:D006069',
#    'drug': 'Ceftriaxone',
#    'drug_mesh': 'MESH:D002443',
#    'drugbank': 'DB:DB01212'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D002443',
#     'target': 'UniProt:P0A3M6'},
#    {'key': 'positively regulates',
#     'source': 'UniProt:P0A3M6',
#     'target': 'GO:0009252'},
#    {'key': 'occurs in', 'source': 'GO:0009252', 'target': 'taxonomy:485'},
#    {'key': 'causes', 'source': 'taxonomy:485', 'target': 'MESH:D006069'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D002443', 'label': 'Drug', 'name': 'Ceftriaxone'},
#    {'id': 'UniProt:P0A3M6',
#     'label': 'Protein',
#     'name': 'Penicillin-binding protein 2B'},
#    {'id': 'GO:0009252',
#     'label': 'BiologicalProcess',
#     'name': 'peptidoglycan biosynthetic process'},
#    {'id': 'taxonomy:485',
#     'label': 'OrganismTaxon',
#     'name': 'Neisseria gonorrhoeae'},
#    {'id': 'MESH:D006069', 'label': 'Disease', 'name': 'Gonorrhea'}],
#   'reference': ['https://go.drugbank.com/drugs/DB01212#mechanism-of-action',
#    'https://www.uniprot.org/uniprot/P0A3M6#function',
#    'https://en.wikipedia.org/wiki/Gonorrhea']},
#  {'directed': True,
#   'graph': {'_id': 'DB02703_MESH_D000881_1',
#    'disease': 'Anthrax',
#    'disease_mesh': 'MESH:D000881',
#    'drug': 'fusidic acid',
#    'drug_mesh': 'MESH:D005672',
#    'drugbank': 'DB:DB02703'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D005672',
#     'target': 'UniProt:Q81VT3'},
#    {'key': 'participates in',
#     'source': 'UniProt:Q81VT3',
#     'target': 'GO:0006412'},
#    {'key': 'occurs in', 'source': 'GO:0006412', 'target': 'taxonomy:1392'},
#    {'key': 'causes', 'source': 'taxonomy:1392', 'target': 'MESH:D000881'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D005672', 'label': 'Drug', 'name': 'fusidic acid'},
#    {'id': 'UniProt:Q81VT3', 'label': 'Protein', 'name': 'elongation factor g'},
#    {'id': 'GO:0006412',
#     'label': 'BiologicalProcess',
#     'name': 'Bacterial Translation'},
#    {'id': 'taxonomy:1392',
#     'label': 'OrganismTaxon',
#     'name': 'Bacillus anthracis'},
#    {'id': 'MESH:D000881', 'label': 'Disease', 'name': 'Anthrax'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00682_MESH_D011655_1',
#    'disease': 'Pulmonary embolism',
#    'disease_mesh': 'MESH:D011655',
#    'drug': 'warfarin',
#    'drug_mesh': 'MESH:D014859',
#    'drugbank': 'DB:DB00682'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D014859',
#     'target': 'UniProt:Q9BQB6'},
#    {'key': 'produces', 'source': 'UniProt:Q9BQB6', 'target': 'MESH:D014812'},
#    {'key': 'participates in',
#     'source': 'MESH:D014812',
#     'target': 'GO:0007596'},
#    {'key': 'causes', 'source': 'GO:0007596', 'target': 'MESH:D011655'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D014859', 'label': 'Drug', 'name': 'warfarin'},
#    {'id': 'UniProt:Q9BQB6', 'label': 'Protein', 'name': 'vitamin k reductase'},
#    {'id': 'MESH:D014812',
#     'label': 'ChemicalSubstance',
#     'name': 'reduced vitamin k'},
#    {'id': 'GO:0007596',
#     'label': 'BiologicalProcess',
#     'name': 'Coagulation factor Synthesis'},
#    {'id': 'MESH:D011655', 'label': 'Disease', 'name': 'Pulmonary embolism'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB09046_MESH_D008060_1',
#    'disease': 'lipodystrophy',
#    'disease_mesh': 'MESH:D008060',
#    'drug': 'metreleptin',
#    'drug_mesh': 'MESH:C415771',
#    'drugbank': 'DB:DB09046'},
#   'links': [{'key': 'increases activity of',
#     'source': 'MESH:C415771',
#     'target': 'UniProt:P48357'},
#    {'key': 'regulates', 'source': 'UniProt:P48357', 'target': 'GO:0060612'},
#    {'key': 'negatively correlated with',
#     'source': 'GO:0060612',
#     'target': 'MESH:D008060'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:C415771', 'label': 'Drug', 'name': 'metreleptin'},
#    {'id': 'UniProt:P48357', 'label': 'Protein', 'name': 'leptin receptor'},
#    {'id': 'GO:0060612', 'label': 'BiologicalProcess', 'name': 'adipogenesis'},
#    {'id': 'MESH:D008060', 'label': 'Disease', 'name': 'lipodystrophy'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB01332_MESH_D007710_1',
#    'disease': 'Klebsiella cystitis',
#    'disease_mesh': 'MESH:D007710',
#    'drug': 'ceftizoxime',
#    'drug_mesh': 'MESH:D015296',
#    'drugbank': 'DB:DB01332'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D015296',
#     'target': 'TIGR:02074'},
#    {'key': 'participates in', 'source': 'TIGR:02074', 'target': 'GO:0009252'},
#    {'key': 'occurs in', 'source': 'GO:0009252', 'target': 'taxonomy:573'},
#    {'key': 'causes', 'source': 'taxonomy:573', 'target': 'MESH:D007710'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D015296', 'label': 'Drug', 'name': 'ceftizoxime'},
#    {'id': 'TIGR:02074',
#     'label': 'GeneFamily',
#     'name': 'Penicillin-binding protein 1A'},
#    {'id': 'GO:0009252',
#     'label': 'BiologicalProcess',
#     'name': 'Bacterial Cell Wall Synthesis'},
#    {'id': 'taxonomy:573',
#     'label': 'OrganismTaxon',
#     'name': 'Klebsiella pneumoniae'},
#    {'id': 'MESH:D007710', 'label': 'Disease', 'name': 'Klebsiella cystitis'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00455_MESH_D065631_1',
#    'disease': 'Allergic Rhinitis',
#    'disease_mesh': 'MESH:D065631',
#    'drug': 'loratadine',
#    'drug_mesh': 'MESH:D017336',
#    'drugbank': 'DB:DB00455'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D017336',
#     'target': 'UniProt:P35367'},
#    {'key': 'participates in',
#     'source': 'UniProt:P35367',
#     'target': 'GO:0034776'},
#    {'key': 'causes', 'source': 'GO:0034776', 'target': 'MESH:D065631'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D017336', 'label': 'Drug', 'name': 'loratadine'},
#    {'id': 'UniProt:P35367',
#     'label': 'Protein',
#     'name': 'histamine H1 Receptor'},
#    {'id': 'GO:0034776',
#     'label': 'BiologicalProcess',
#     'name': 'histamine response'},
#    {'id': 'MESH:D065631', 'label': 'Disease', 'name': 'Allergic Rhinitis'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00935_MESH_D015508_1',
#    'disease': 'Nasal Congestion',
#    'disease_mesh': 'MESH:D015508',
#    'drug': 'oxymetazoline',
#    'drug_mesh': 'MESH:D010109',
#    'drugbank': 'DB:DB00935'},
#   'links': [{'key': 'increases activity of',
#     'source': 'MESH:D010109',
#     'target': 'UniProt:P35348'},
#    {'key': 'positively regulates',
#     'source': 'UniProt:P35348',
#     'target': 'GO:0042310'},
#    {'key': 'prevents', 'source': 'GO:0042310', 'target': 'MESH:D015508'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D010109', 'label': 'Drug', 'name': 'oxymetazoline'},
#    {'id': 'UniProt:P35348',
#     'label': 'Protein',
#     'name': 'Alpha-1a adrenergic receptor'},
#    {'id': 'GO:0042310',
#     'label': 'BiologicalProcess',
#     'name': 'Vasoconstriction'},
#    {'id': 'MESH:D015508', 'label': 'Disease', 'name': 'Nasal Congestion'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB01174_MESH_D004827_1',
#    'disease': 'Epilepsy',
#    'disease_mesh': 'MESH:D004827',
#    'drug': 'phenobarbital',
#    'drug_mesh': 'MESH:D010634',
#    'drugbank': 'DB:DB01174'},
#   'links': [{'key': 'increases activity of',
#     'source': 'MESH:D010634',
#     'target': 'InterPro:IPR006028'},
#    {'key': 'participates in',
#     'source': 'InterPro:IPR006028',
#     'target': 'GO:0099536'},
#    {'key': 'negatively correlated with',
#     'source': 'GO:0099536',
#     'target': 'MESH:D004827'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D010634', 'label': 'Drug', 'name': 'phenobarbital'},
#    {'id': 'InterPro:IPR006028',
#     'label': 'GeneFamily',
#     'name': 'GABAA Receptors'},
#    {'id': 'GO:0099536',
#     'label': 'BiologicalProcess',
#     'name': 'Synaptic Signaling'},
#    {'id': 'MESH:D004827', 'label': 'Disease', 'name': 'Epilepsy'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00281_MESH_D010146_1',
#    'disease': 'Pain',
#    'disease_mesh': 'MESH:D010146',
#    'drug': 'lidocaine',
#    'drug_mesh': 'MESH:D008012',
#    'drugbank': 'DB:DB00281'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D008012',
#     'target': 'InterPro:IPR028809'},
#    {'key': 'participates in',
#     'source': 'InterPro:IPR028809',
#     'target': 'GO:0019233'},
#    {'key': 'causes', 'source': 'GO:0019233', 'target': 'MESH:D010146'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D008012', 'label': 'Drug', 'name': 'lidocaine'},
#    {'id': 'InterPro:IPR028809',
#     'label': 'GeneFamily',
#     'name': 'Neuronal Voltage gated sodium channels'},
#    {'id': 'GO:0019233',
#     'label': 'BiologicalProcess',
#     'name': 'Sensory perception of pain'},
#    {'id': 'MESH:D010146', 'label': 'Disease', 'name': 'Pain'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00476_MESH_D003865_1',
#    'disease': 'major depressive disorder',
#    'disease_mesh': 'MESH:D003865',
#    'drug': 'duloxetine',
#    'drug_mesh': 'MESH:D000068736',
#    'drugbank': 'DB:DB00476'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D000068736',
#     'target': 'UniProt:P31645'},
#    {'key': 'participates in',
#     'source': 'UniProt:P31645',
#     'target': 'GO:0051610'},
#    {'key': 'causes', 'source': 'GO:0051610', 'target': 'MESH:D003865'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D000068736', 'label': 'Drug', 'name': 'duloxetine'},
#    {'id': 'UniProt:P31645',
#     'label': 'Protein',
#     'name': 'sodium dependent serotonin transporter'},
#    {'id': 'GO:0051610',
#     'label': 'BiologicalProcess',
#     'name': 'Neuronal serotonin reuptake'},
#    {'id': 'MESH:D003865',
#     'label': 'Disease',
#     'name': 'major depressive disorder'}]},
#  {'directed': True,
#   'graph': {'_id': 'DB00366_MESH_D065631_1',
#    'disease': 'Allergic Rhinitis',
#    'disease_mesh': 'MESH:D065631',
#    'drug': 'doxylamine',
#    'drug_mesh': 'MESH:D004319',
#    'drugbank': 'DB:DB00366'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D004319',
#     'target': 'UniProt:P35367'},
#    {'key': 'participates in',
#     'source': 'UniProt:P35367',
#     'target': 'GO:0034776'},
#    {'key': 'causes', 'source': 'GO:0034776', 'target': 'MESH:D065631'}],
#   'multigraph': True,
# ...
#     'source': 'MESH:D014011',
#     'target': 'GO:0000305'},
#    {'key': 'disrupts', 'source': 'GO:0000305', 'target': 'MESH:D004247'},
#    {'key': 'in taxon', 'source': 'MESH:D004247', 'target': 'taxonomy:5722'},
#    {'key': 'causes', 'source': 'taxonomy:5722', 'target': 'MESH:D014245'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D014011', 'label': 'Drug', 'name': 'Tinidazole'},
#    {'id': 'GO:0000305',
#     'label': 'BiologicalProcess',
#     'name': 'Response to oxygen radical'},
#    {'id': 'MESH:D004247', 'label': 'ChemicalSubstance', 'name': 'DNA'},
#    {'id': 'taxonomy:5722',
#     'label': 'OrganismTaxon',
#     'name': 'Trichomonas vaginalis'},
#    {'id': 'MESH:D014245',
#     'label': 'Disease',
#     'name': 'Infection by Trichomonas'}],
#   'reference': ['https://go.drugbank.com/drugs/DB00911',
#    'https://en.wikipedia.org/wiki/Trichomoniasis#Treatment']},
#  {'comment': 'Tinidazole is a prodrug',
#   'directed': True,
#   'graph': {'_id': 'DB00911_MESH_D005873_1',
#    'disease': 'Giardiasis',
#    'disease_mesh': 'MESH:D005873',
#    'drug': 'Tinidazole',
#    'drug_mesh': 'MESH:D014011',
#    'drugbank': 'DB:DB00911'},
#   'links': [{'key': 'positively regulates',
#     'source': 'MESH:D014011',
#     'target': 'GO:0000305'},
#    {'key': 'disrupts', 'source': 'GO:0000305', 'target': 'MESH:D004247'},
#    {'key': 'in taxon', 'source': 'MESH:D004247', 'target': 'taxonomy:5741'},
#    {'key': 'causes', 'source': 'taxonomy:5741', 'target': 'MESH:D005873'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D014011', 'label': 'Drug', 'name': 'Tinidazole'},
#    {'id': 'GO:0000305',
#     'label': 'BiologicalProcess',
#     'name': 'Response to oxygen radical'},
#    {'id': 'MESH:D004247', 'label': 'ChemicalSubstance', 'name': 'DNA'},
#    {'id': 'taxonomy:5741',
#     'label': 'OrganismTaxon',
#     'name': 'Giardia intestinalis'},
#    {'id': 'MESH:D005873', 'label': 'Disease', 'name': 'Giardiasis'}],
#   'reference': ['https://go.drugbank.com/drugs/DB00911',
#    'https://en.wikipedia.org/wiki/Giardiasis']},
#  {'directed': True,
#   'graph': {'_id': 'DB01117_MESH_D016778_1',
#    'disease': 'Falciparum malaria',
#    'disease_mesh': 'MESH:D016778',
#    'drug': 'Atovaquone',
#    'drug_mesh': 'MESH:D053626',
#    'drugbank': 'DB:DB01117'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D053626',
#     'target': 'UniProt:Q02768'},
#    {'key': 'decreases activity of',
#     'source': 'MESH:D053626',
#     'target': 'UniProt:Q08210'},
#    {'key': 'positively regulates',
#     'source': 'UniProt:Q02768',
#     'target': 'GO:0042773'},
#    {'key': 'positively regulates',
#     'source': 'UniProt:Q08210',
#     'target': 'GO:0019856'},
#    {'key': 'in taxon', 'source': 'GO:0042773', 'target': 'taxonomy:5833'},
#    {'key': 'in taxon', 'source': 'GO:0019856', 'target': 'taxonomy:5833'},
#    {'key': 'causes', 'source': 'taxonomy:5833', 'target': 'MESH:D016778'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D053626', 'label': 'Drug', 'name': 'Atovaquone'},
#    {'id': 'UniProt:Q02768',
#     'label': 'Protein',
#     'name': 'Cytochrome b (Plasmodium falciparum)'},
#    {'id': 'UniProt:Q08210',
#     'label': 'Protein',
#     'name': 'Dihydroorotate dehydrogenase (quinone), mitochondrial'},
#    {'id': 'GO:0042773',
#     'label': 'BiologicalProcess',
#     'name': 'ATP synthesis coupled electron transport'},
#    {'id': 'GO:0019856',
#     'label': 'BiologicalProcess',
#     'name': 'Pyrimidine nucleobase biosynthetic process'},
#    {'id': 'taxonomy:5833',
#     'label': 'OrganismTaxon',
#     'name': 'Plasmodium falciparum'},
#    {'id': 'MESH:D016778', 'label': 'Disease', 'name': 'Falciparum malaria'}],
#   'reference': ['https://go.drugbank.com/drugs/DB01117#BE0004428']},
#  {'directed': True,
#   'graph': {'_id': 'DB01139_MESH_D004697_1',
#    'disease': 'Bacterial endocarditis',
#    'disease_mesh': 'MESH:D004697',
#    'drug': 'Cefapirin',
#    'drug_mesh': 'MESH:D002514',
#    'drugbank': 'DB:DB01139'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D002514',
#     'target': 'InterPro:IPR001460'},
#    {'key': 'positively regulates',
#     'source': 'InterPro:IPR001460',
#     'target': 'GO:0018104'},
#    {'key': 'positively regulates',
#     'source': 'GO:0018104',
#     'target': 'GO:0009273'},
#    {'key': 'has output', 'source': 'GO:0009273', 'target': 'GO:0005618'},
#    {'key': 'occurs in', 'source': 'GO:0005618', 'target': 'taxonomy:1280'},
#    {'key': 'causes', 'source': 'taxonomy:1280', 'target': 'MESH:D004697'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D002514', 'label': 'Drug', 'name': 'Cefapirin'},
#    {'id': 'InterPro:IPR001460',
#     'label': 'GeneFamily',
#     'name': 'Penicillin-binding protein, transpeptidase'},
#    {'id': 'GO:0018104',
#     'label': 'BiologicalProcess',
#     'name': 'Cross-linking of the peptidoglycan'},
#    {'id': 'GO:0009273',
#     'label': 'BiologicalProcess',
#     'name': 'Peptidoglycan-based cell wall biogenesis'},
#    {'id': 'GO:0005618', 'label': 'CellularComponent', 'name': 'Cell wall'},
#    {'id': 'taxonomy:1280',
#     'label': 'OrganismTaxon',
#     'name': 'Staphylococcus aureus'},
#    {'id': 'MESH:D004697',
#     'label': 'Disease',
#     'name': 'Bacterial endocarditis'}],
#   'reference': ['https://go.drugbank.com/drugs/DB01139',
#    'https://en.wikipedia.org/wiki/Infective_endocarditis#Cause']},
#  {'directed': True,
#   'graph': {'_id': 'DB01139_MESH_D012226_1',
#    'disease': 'Rhinoscleroma',
#    'disease_mesh': 'MESH:D012226',
#    'drug': 'Cefapirin',
#    'drug_mesh': 'MESH:D002514',
#    'drugbank': 'DB:DB01139'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D002514',
#     'target': 'InterPro:IPR001460'},
#    {'key': 'positively regulates',
#     'source': 'InterPro:IPR001460',
#     'target': 'GO:0018104'},
#    {'key': 'positively regulates',
#     'source': 'GO:0018104',
#     'target': 'GO:0009273'},
#    {'key': 'has output', 'source': 'GO:0009273', 'target': 'GO:0005618'},
#    {'key': 'occurs in', 'source': 'GO:0005618', 'target': 'taxonomy:39831'},
#    {'key': 'causes', 'source': 'taxonomy:39831', 'target': 'MESH:D012226'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D002514', 'label': 'Drug', 'name': 'Cefapirin'},
#    {'id': 'InterPro:IPR001460',
#     'label': 'GeneFamily',
#     'name': 'Penicillin-binding protein, transpeptidase'},
#    {'id': 'GO:0018104',
#     'label': 'BiologicalProcess',
#     'name': 'Cross-linking of the peptidoglycan'},
#    {'id': 'GO:0009273',
#     'label': 'BiologicalProcess',
#     'name': 'Peptidoglycan-based cell wall biogenesis'},
#    {'id': 'GO:0005618', 'label': 'CellularComponent', 'name': 'Cell wall'},
#    {'id': 'taxonomy:39831',
#     'label': 'OrganismTaxon',
#     'name': 'Klebsiella pneumoniae subsp. rhinoscleromatis'},
#    {'id': 'MESH:D012226', 'label': 'Disease', 'name': 'Rhinoscleroma'}],
#   'reference': ['https://go.drugbank.com/drugs/DB01139',
#    'https://en.wikipedia.org/wiki/Rhinoscleroma']},
#  {'directed': True,
#   'graph': {'_id': 'DB01139_MESH_D004927_1',
#    'disease': 'Infection due to Escherichia coli',
#    'disease_mesh': 'MESH:D004927',
#    'drug': 'Cefapirin',
#    'drug_mesh': 'MESH:D002514',
#    'drugbank': 'DB:DB01139'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D002514',
#     'target': 'InterPro:IPR001460'},
#    {'key': 'positively regulates',
#     'source': 'InterPro:IPR001460',
#     'target': 'GO:0018104'},
#    {'key': 'positively regulates',
#     'source': 'GO:0018104',
#     'target': 'GO:0009273'},
#    {'key': 'has output', 'source': 'GO:0009273', 'target': 'GO:0005618'},
#    {'key': 'occurs in', 'source': 'GO:0005618', 'target': 'taxonomy:562'},
#    {'key': 'causes', 'source': 'taxonomy:562', 'target': 'MESH:D004927'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D002514', 'label': 'Drug', 'name': 'Cefapirin'},
#    {'id': 'InterPro:IPR001460',
#     'label': 'GeneFamily',
#     'name': 'Penicillin-binding protein, transpeptidase'},
#    {'id': 'GO:0018104',
#     'label': 'BiologicalProcess',
#     'name': 'Cross-linking of the peptidoglycan'},
#    {'id': 'GO:0009273',
#     'label': 'BiologicalProcess',
#     'name': 'Peptidoglycan-based cell wall biogenesis'},
#    {'id': 'GO:0005618', 'label': 'CellularComponent', 'name': 'Cell wall'},
#    {'id': 'taxonomy:562',
#     'label': 'OrganismTaxon',
#     'name': 'Escherichia coli'},
#    {'id': 'MESH:D004927',
#     'label': 'Disease',
#     'name': 'Infection due to Escherichia coli'}],
#   'reference': ['https://go.drugbank.com/drugs/DB01139']},
#  {'directed': True,
#   'graph': {'_id': 'DB01139_MESH_D013203_1',
#    'disease': 'Infection due to Staphylococcus aureus',
#    'disease_mesh': 'MESH:D013203',
#    'drug': 'Cefapirin',
#    'drug_mesh': 'MESH:D002514',
#    'drugbank': 'DB:DB01139'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D002514',
#     'target': 'InterPro:IPR001460'},
#    {'key': 'positively regulates',
#     'source': 'InterPro:IPR001460',
#     'target': 'GO:0018104'},
#    {'key': 'positively regulates',
#     'source': 'GO:0018104',
#     'target': 'GO:0009273'},
#    {'key': 'has output', 'source': 'GO:0009273', 'target': 'GO:0005618'},
#    {'key': 'occurs in', 'source': 'GO:0005618', 'target': 'taxonomy:1280'},
#    {'key': 'causes', 'source': 'taxonomy:1280', 'target': 'MESH:D013203'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D002514', 'label': 'Drug', 'name': 'Cefapirin'},
#    {'id': 'InterPro:IPR001460',
#     'label': 'GeneFamily',
#     'name': 'Penicillin-binding protein, transpeptidase'},
#    {'id': 'GO:0018104',
#     'label': 'BiologicalProcess',
#     'name': 'Cross-linking of the peptidoglycan'},
#    {'id': 'GO:0009273',
#     'label': 'BiologicalProcess',
#     'name': 'Peptidoglycan-based cell wall biogenesis'},
#    {'id': 'GO:0005618', 'label': 'CellularComponent', 'name': 'Cell wall'},
#    {'id': 'taxonomy:1280',
#     'label': 'OrganismTaxon',
#     'name': 'Staphylococcus aureus'},
#    {'id': 'MESH:D013203',
#     'label': 'Disease',
#     'name': 'Infection due to Staphylococcus aureus'}],
#   'reference': ['https://go.drugbank.com/drugs/DB01139']},
#  {'directed': True,
#   'graph': {'_id': 'DB01139_MESH_D011023_1',
#    'disease': 'Staphylococcal pneumonia',
#    'disease_mesh': 'MESH:D011023',
#    'drug': 'Cefapirin',
#    'drug_mesh': 'MESH:D002514',
#    'drugbank': 'DB:DB01139'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D002514',
#     'target': 'InterPro:IPR001460'},
#    {'key': 'positively regulates',
#     'source': 'InterPro:IPR001460',
#     'target': 'GO:0018104'},
#    {'key': 'positively regulates',
#     'source': 'GO:0018104',
#     'target': 'GO:0009273'},
#    {'key': 'has output', 'source': 'GO:0009273', 'target': 'GO:0005618'},
#    {'key': 'occurs in', 'source': 'GO:0005618', 'target': 'taxonomy:1279'},
#    {'key': 'causes', 'source': 'taxonomy:1279', 'target': 'MESH:D011023'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D002514', 'label': 'Drug', 'name': 'Cefapirin'},
#    {'id': 'InterPro:IPR001460',
#     'label': 'GeneFamily',
#     'name': 'Penicillin-binding protein, transpeptidase'},
#    {'id': 'GO:0018104',
#     'label': 'BiologicalProcess',
#     'name': 'Cross-linking of the peptidoglycan'},
#    {'id': 'GO:0009273',
#     'label': 'BiologicalProcess',
#     'name': 'Peptidoglycan-based cell wall biogenesis'},
#    {'id': 'GO:0005618', 'label': 'CellularComponent', 'name': 'Cell wall'},
#    {'id': 'taxonomy:1279', 'label': 'OrganismTaxon', 'name': 'Staphylococcus'},
#    {'id': 'MESH:D011023',
#     'label': 'Disease',
#     'name': 'Staphylococcal pneumonia'}],
#   'reference': ['https://go.drugbank.com/drugs/DB01139']},
#  {'directed': True,
#   'graph': {'_id': 'DB01139_MESH_D011014_1',
#    'disease': 'Pneumonia',
#    'disease_mesh': 'MESH:D011014',
#    'drug': 'Cefapirin',
#    'drug_mesh': 'MESH:D002514',
#    'drugbank': 'DB:DB01139'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D002514',
#     'target': 'InterPro:IPR001460'},
#    {'key': 'positively regulates',
#     'source': 'InterPro:IPR001460',
#     'target': 'GO:0018104'},
#    {'key': 'positively regulates',
#     'source': 'GO:0018104',
#     'target': 'GO:0009273'},
#    {'key': 'has output', 'source': 'GO:0009273', 'target': 'GO:0005618'},
#    {'key': 'occurs in', 'source': 'GO:0005618', 'target': 'taxonomy:2'},
#    {'key': 'causes', 'source': 'taxonomy:2', 'target': 'MESH:D011014'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D002514', 'label': 'Drug', 'name': 'Cefapirin'},
#    {'id': 'InterPro:IPR001460',
#     'label': 'GeneFamily',
#     'name': 'Penicillin-binding protein, transpeptidase'},
#    {'id': 'GO:0018104',
#     'label': 'BiologicalProcess',
#     'name': 'Cross-linking of the peptidoglycan'},
#    {'id': 'GO:0009273',
#     'label': 'BiologicalProcess',
#     'name': 'Peptidoglycan-based cell wall biogenesis'},
#    {'id': 'GO:0005618', 'label': 'CellularComponent', 'name': 'Cell wall'},
#    {'id': 'taxonomy:2', 'label': 'OrganismTaxon', 'name': 'Bacteria'},
#    {'id': 'MESH:D011014', 'label': 'Disease', 'name': 'Pneumonia'}],
#   'reference': ['https://go.drugbank.com/drugs/DB01139',
#    'https://en.wikipedia.org/wiki/Pneumonia#Cause']},
#  {'directed': True,
#   'graph': {'_id': 'DB01139_MESH_D011018_1',
#    'disease': 'Pneumonia due to Streptococcus',
#    'disease_mesh': 'MESH:D011018',
#    'drug': 'Cefapirin',
#    'drug_mesh': 'MESH:D002514',
#    'drugbank': 'DB:DB01139'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D002514',
#     'target': 'InterPro:IPR001460'},
#    {'key': 'positively regulates',
#     'source': 'InterPro:IPR001460',
#     'target': 'GO:0018104'},
#    {'key': 'positively regulates',
#     'source': 'GO:0018104',
#     'target': 'GO:0009273'},
#    {'key': 'has output', 'source': 'GO:0009273', 'target': 'GO:0005618'},
#    {'key': 'occurs in', 'source': 'GO:0005618', 'target': 'taxonomy:1313'},
#    {'key': 'causes', 'source': 'taxonomy:1313', 'target': 'MESH:D011018'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D002514', 'label': 'Drug', 'name': 'Cefapirin'},
#    {'id': 'InterPro:IPR001460',
#     'label': 'GeneFamily',
#     'name': 'Penicillin-binding protein, transpeptidase'},
#    {'id': 'GO:0018104',
#     'label': 'BiologicalProcess',
#     'name': 'Cross-linking of the peptidoglycan'},
#    {'id': 'GO:0009273',
#     'label': 'BiologicalProcess',
#     'name': 'Peptidoglycan-based cell wall biogenesis'},
#    {'id': 'GO:0005618', 'label': 'CellularComponent', 'name': 'Cell wall'},
#    {'id': 'taxonomy:1313',
#     'label': 'OrganismTaxon',
#     'name': 'Streptococcus pneumoniae'},
#    {'id': 'MESH:D011018',
#     'label': 'Disease',
#     'name': 'Pneumonia due to Streptococcus'}],
#   'reference': ['https://go.drugbank.com/drugs/DB01139',
#    'https://en.wikipedia.org/wiki/Streptococcus_pneumoniae']},
#  {'directed': True,
#   'graph': {'_id': 'DB01139_MESH_D013290_1',
#    'disease': 'Streptococcus pyogenes infection',
#    'disease_mesh': 'MESH:D013290',
#    'drug': 'Cefapirin',
#    'drug_mesh': 'MESH:D002514',
#    'drugbank': 'DB:DB01139'},
#   'links': [{'key': 'decreases activity of',
#     'source': 'MESH:D002514',
#     'target': 'InterPro:IPR001460'},
#    {'key': 'positively regulates',
#     'source': 'InterPro:IPR001460',
#     'target': 'GO:0018104'},
#    {'key': 'positively regulates',
#     'source': 'GO:0018104',
#     'target': 'GO:0009273'},
#    {'key': 'has output', 'source': 'GO:0009273', 'target': 'GO:0005618'},
#    {'key': 'occurs in', 'source': 'GO:0005618', 'target': 'taxonomy:1314'},
#    {'key': 'causes', 'source': 'taxonomy:1314', 'target': 'MESH:D013290'}],
#   'multigraph': True,
#   'nodes': [{'id': 'MESH:D002514', 'label': 'Drug', 'name': 'Cefapirin'},
#    {'id': 'InterPro:IPR001460',
#     'label': 'GeneFamily',
#     'name': 'Penicillin-binding protein, transpeptidase'},
#    {'id': 'GO:0018104',
#     'label': 'BiologicalProcess',
#     'name': 'Cross-linking of the peptidoglycan'},
#    {'id': 'GO:0009273',
#     'label': 'BiologicalProcess',
#     'name': 'Peptidoglycan-based cell wall biogenesis'},
#    {'id': 'GO:0005618', 'label': 'CellularComponent', 'name': 'Cell wall'},
#    {'id': 'taxonomy:1314',
#     'label': 'OrganismTaxon',
#     'name': 'Streptococcus pyogenes'},
#    {'id': 'MESH:D013290',
#     'label': 'Disease',
#     'name': 'Streptococcus pyogenes infection'}],
#   'reference': ['https://go.drugbank.com/drugs/DB01139']},
#  ...]

# %%
### Parse YAML file extracting Node ID and their associated Names for each graph

def extract_graph_node_data(drug_db):
    # Initialize a list to store the extracted data
    node_data = []
    
    for graph in drug_db:
        graph_id = graph['graph']['_id']  # Accessing the graph ID
        nodes = graph['nodes']
        node_list = []

        for node in nodes:
            node_id = node['id']
            node_name = node['name']
            node_list.append({'id': node_id, 'name': node_name})

        node_data.append({
            'graph': {
                '_id': graph_id,
                'nodes': node_list
            }
        })

    return node_data  # list of dictionaries with nested 'nodes' under 'graph'

graphs = extract_graph_node_data(drug_db)

# Display DrugMechDB Node ID & Names for each graph
#graphs

# %%
# Screen for outdated node id's

def extract_unique_prefixes(graphs):
    unique_prefixes = set()

    for graph in graphs:
        for node in graph['graph']['nodes']:
            prefix = node['id'].split(':', 1)[0]  # Extract prefix before the colon
            unique_prefixes.add(prefix)  # Add to the set, duplicates will not be added

    return unique_prefixes

unique_prefixes = extract_unique_prefixes(graphs)

# Display the set of unique node id prefixes; shows all the node ide prefixes that are in DrugMechDB
print("DrugMechDB Node ID prefixes:", unique_prefixes)
# Out:
# DrugMechDB Node ID prefixes: {'HP', 'PR', 'reactome', 'taxonomy', 'TIGR', 'InterPro', 'GO', 'MESH', 'CHEBI', 'DB', 'CL', 'UniProt', 'Pfam', 'UBERON'}

# %%
curie_prefixes = {
    "ATC": "ATC",
    "BIOLINK": "biolink",
    "BIOLINK_SOURCE": "biolink_download_source",
    "CHEBI": "CHEBI",
    "CHEMBL_COMPOUND": "CHEMBL.COMPOUND",
    "CHEMBL_MECHANISM": "CHEMBL.MECHANISM",
    "CHEMBL_TARGET": "CHEMBL.TARGET",
    "CHV": "CHV",
    "CLINICALTRIALS": "clinicaltrials",
    "DCTERMS": "dcterms",
    "DGIDB": "DGIdb",
    "DOID": "DOID",
    "DRUGBANK": "DRUGBANK",
    "DRUGCENTRAL": "DrugCentral",
    "ENSEMBL": "ENSEMBL",
    "ENSEMBL_GENOMES": "EnsemblGenomes",
    "FMA": "FMA",
    "GO": "GO",
    "GTPI": "GTPI",
    "GTPI_SOURCE": "GTPI_source",
    "HCPCS": "HCPCS",
    "HGNC": "HGNC",
    "HMDB": "HMDB",
    "HP": "HP",
    "IAO": "IAO",
    "ICD10PCS": "ICD10PCS",
    "ICD9": "ICD9",
    "IDENTIFIERS_ORG_REGISTRY": "identifiers_org_registry",
    "ISBN": "ISBN",
    "KEGG": "KEGG",
    "KEGG_COMPOUND": "KEGG.COMPOUND",
    "KEGG_DRUG": "KEGG.DRUG",
    "KEGG_ENZYME": "KEGG.ENZYME",
    "KEGG_GLYCAN": "KEGG.GLYCAN",
    "KEGG_REACTION": "KEGG.REACTION",
    "KEGG_SOURCE": "KEGG_source",
    "MEDDRA": "MEDDRA",
    "MESH": "MESH",
    "MIRBASE": "miRBase",
    "MONDO": "MONDO",
    "NCBI_GENE": "NCBIGene",
    "NCBI_TAXON": "NCBITaxon",
    "NCIT": "NCIT",
    "NDDF": "NDDF",
    "OBO": "OBO",
    "OBO_FORMAT": "oboFormat",
    "OIO": "OIO",
    "OMIM": "OMIM",
    "OWL": "owl",
    "PATHWHIZ": "PathWhiz",
    "PATHWHIZ_COMPOUND": "PathWhiz.Compound",
    "PATHWHIZ_NUCLEIC_ACID": "PathWhiz.NucleicAcid",
    "PATHWHIZ_ELEMENT_COLLECTION": "PathWhiz.ElementCollection",
    "PATHWHIZ_REACTION": "PathWhiz.Reaction",
    "PATHWHIZ_BOUND": "PathWhiz.Bound",
    "PATHWHIZ_PROTEIN_COMPLEX": "PathWhiz.ProteinComplex",
    "PDQ": "PDQ",
    "PMID": "PMID",
    "PSY": "PSY",
    "RDF": "rdf",
    "RDFS": "rdfs",
    "REACTOME": "REACT",
    "REPODB": "REPODB",
    "RHEA": "RHEA",
    "RHEA_COMP": "RHEA.COMP",
    "RO": "RO",
    "RTX": "RTX",
    "RXNORM": "RXNORM",
    "SEMMEDDB": "SEMMEDDB",
    "SKOS": "skos",
    "SMPDB": "SMPDB",
    "SNOMED": "SNOMED",
    "TTD_DRUG": "ttd.drug",
    "TTD_TARGET": "ttd.target",
    "UMLS": "UMLS",
    "UMLS_STY": "STY",
    "UMLS_SOURCE": "umls_source",
    "UNICHEM_SOURCE": "UNICHEM_source",
    "UNIPROT": "UniProtKB",
    "VANDF": "VANDF"
} # curies_prefix is prefiexes from RTX-KG2 
    
def update_node_ids(graphs, curie_prefixes):
    # Convert all dictionary keys to uppercase for case-insensitive matching
    curie_prefixes = {k.upper(): v for k, v in curie_prefixes.items()}
    unmatched_prefixes = set()
    
    for graph in graphs:
        for node in graph['graph']['nodes']:
            original_id = node['id']
            prefix, id_suffix = original_id.split(':', 1)
            upper_prefix = prefix.upper()
            
            if upper_prefix in curie_prefixes:
                # Use the uppercased prefix to fetch the correct replacement
                node['id'] = f"{curie_prefixes[upper_prefix]}:{id_suffix}"
            else:
                unmatched_prefixes.add(prefix)  # Collect unmatched prefixes
    if unmatched_prefixes:
        print("Unmatched prefixes:", unmatched_prefixes)
        print()
    return graphs

# Displays updated node IDs for each graph and unmatched node id prefixes
# The unmatched node ID's will be processed in the later script using equivalent query match
graphs_converted = update_node_ids(graphs, curie_prefixes)

# Display updated DrugMechDB graph node id (prefix update)
graphs_converted
# Out:
# Unmatched prefixes: {'PR', 'taxonomy', 'TIGR', 'UBERON', 'DB', 'CL', 'Pfam', 'InterPro'}
# [{'graph': {'_id': 'DB00619_MESH_D015464_1',
#    'nodes': [{'id': 'MESH:D000068877', 'name': 'imatinib'},
#     {'id': 'UniProtKB:P00519', 'name': 'BCR/ABL'},
#     {'id': 'MESH:D015464', 'name': 'CML (ph+)'}]}},
#  {'graph': {'_id': 'DB00619_MESH_D034721_1',
#    'nodes': [{'id': 'MESH:D000068877', 'name': 'imatinib'},
#     {'id': 'UniProtKB:P10721', 'name': 'c-Kit'},
#     {'id': 'UniProtKB:P16234', 'name': 'Pdgf'},
#     {'id': 'GO:0008283', 'name': 'Cellular proliferation'},
#     {'id': 'MESH:D034721', 'name': 'Systemic mast cell disease'}]}},
#  {'graph': {'_id': 'DB00316_MESH_D010146_1',
#    'nodes': [{'id': 'MESH:D000082', 'name': 'Acetaminophen'},
#     {'id': 'UniProtKB:P23219', 'name': 'Prostaglandin G/H synthase 1'},
#     {'id': 'UniProtKB:P35354', 'name': 'Prostaglandin G/H synthase 2'},
#     {'id': 'UniProtKB:Q15185', 'name': 'Prostaglandin E synthase 3'},
#     {'id': 'GO:0001516', 'name': 'prostaglandin biosynthetic process'},
#     {'id': 'MESH:D011453', 'name': 'Prostaglandins'},
#     {'id': 'MESH:D010146', 'name': 'Pain'}]}},
#  {'graph': {'_id': 'DB00316_MESH_D005334_1',
#    'nodes': [{'id': 'MESH:D000082', 'name': 'acetaminophen'},
#     {'id': 'REACT:R-HSA-2162123', 'name': 'cycloxygenaze pathways'},
#     {'id': 'UBERON:0000955', 'name': 'Brain'},
#     {'id': 'GO:0001659', 'name': 'Temperature Homeostasis'},
#     {'id': 'MESH:D005334', 'name': 'Fever'}]}},
#  {'graph': {'_id': 'DB00945_MESH_D010146_1',
#    'nodes': [{'id': 'MESH:D001241', 'name': 'Aspirin'},
#     {'id': 'UniProtKB:P23219', 'name': 'Prostaglandin G/H synthase 1'},
#     {'id': 'UniProtKB:P35354', 'name': 'Prostaglandin G/H synthase 2'},
#     {'id': 'GO:0001516', 'name': 'prostaglandin biosynthetic process'},
#     {'id': 'MESH:D011453', 'name': 'Prostaglandins'},
#     {'id': 'GO:0006954', 'name': 'inflammatory response'},
#     {'id': 'MESH:D010146', 'name': 'Pain'}]}},
#  {'graph': {'_id': 'DB00945_MESH_D013927_1',
#    'nodes': [{'id': 'MESH:D001241', 'name': 'acetylsalicylic acid'},
#     {'id': 'UniProtKB:P23219', 'name': 'COX'},
#     {'id': 'REACT:R-HSA-2162123',
#      'name': 'Synthesis of Prostaglandins and Thromboxanes'},
#     {'id': 'MESH:D013928', 'name': 'Thromboxane A2'},
#     {'id': 'GO:0007596', 'name': 'Platelet Activiation / Blood Coagulation'},
#     {'id': 'MESH:D013927', 'name': 'Thrombosis'}]}},
#  {'graph': {'_id': 'DB00788_MESH_D010146_1',
#    'nodes': [{'id': 'MESH:D009288', 'name': 'naproxen'},
#     {'id': 'UniProtKB:P35354', 'name': 'Cox-2'},
#     {'id': 'MESH:D011453', 'name': 'Prostaglandins'},
#     {'id': 'GO:0006954', 'name': 'Inflammation'},
#     {'id': 'MESH:D010146', 'name': 'Pain'}]}},
#  {'graph': {'_id': 'DB01059_MESH_D004405_1',
#    'nodes': [{'id': 'MESH:D009643', 'name': 'norfloxacin'},
#     {'id': 'UniProtKB:P43702', 'name': 'topoisomerases II, IV'},
#     {'id': 'GO:0003746', 'name': 'Translocation of EF-G'},
#     {'id': 'GO:0006260', 'name': 'Bacterial DNA replication'},
#     {'id': 'GO:0006412', 'name': 'Bacterial Protein Synthesis'},
#     {'id': 'taxonomy:622', 'name': 'Shigella dysenteriae'},
#     {'id': 'MESH:D004405', 'name': 'Shigellosis'}]}},
#  {'graph': {'_id': 'DB01380_MESH_D007634_1',
#    'nodes': [{'id': 'MESH:D003348', 'name': 'cortisone acetate'},
#     {'id': 'UniProtKB:P04150', 'name': 'Glucocorticoid receptor'},
#     {'id': 'UniProtKB:P23219', 'name': 'COX Genes'},
#     {'id': 'UniProtKB:P04083', 'name': 'lipocortin-1'},
#     {'id': 'REACT:R-HSA-2162123', 'name': 'Prostaglandin Synthesis'},
#     {'id': 'MESH:D011453', 'name': 'Prostaglandins'},
#     {'id': 'GO:0050900', 'name': 'Immune Cell Funciton'},
#     {'id': 'GO:0006954', 'name': 'Inflammation'},
#     {'id': 'MESH:D007634', 'name': 'Keratitis'}]}},
#  {'graph': {'_id': 'DB01610_MESH_D003586_1',
#    'nodes': [{'id': 'MESH:D000077562', 'name': 'valganciclovir'},
#     {'id': 'MESH:D015774', 'name': 'ganciclovir'},
#     {'id': 'GO:0039693', 'name': 'viral DNA replication'},
#     {'id': 'taxonomy:10358', 'name': 'Cytomegalovirus'},
#     {'id': 'MESH:D003586', 'name': 'CMV infection'}]}},
#  {'graph': {'_id': 'DB00916_MESH_D018805_1',
#    'nodes': [{'id': 'MESH:D008795', 'name': 'metronidazole'},
#     {'id': 'MESH:C029371', 'name': 'hydroxyethyl oxamic acid'},
#     {'id': 'GO:0003676', 'name': 'bacterial Nucleic Acid synthesis'},
#     {'id': 'taxonomy:2', 'name': 'Bacteria'},
#     {'id': 'MESH:D018805', 'name': 'Bacterial septicemia'}]}},
#  {'graph': {'_id': 'DB00618_MESH_D000073605_1',
#    'nodes': [{'id': 'MESH:D003707', 'name': 'demeclocycline'},
#     {'id': 'UniProtKB:P0A7S3', 'name': '30S Ribosomal Subunit'},
#     {'id': 'UniProtKB:P0A7J3', 'name': '50S Ribosomal Subunit'},
#     {'id': 'GO:0006412', 'name': 'Bacterial Translation'},
#     {'id': 'taxonomy:786', 'name': 'Rickettsia akari'},
#     {'id': 'MESH:D000073605', 'name': 'Rickettsialpox'}]}},
#  {'graph': {'_id': 'DB01060_MESH_D014069_1',
#    'nodes': [{'id': 'MESH:D000658', 'name': 'amoxicillin'},
#     {'id': 'TIGR:02074', 'name': 'Penicillin-binding proteins 1A'},
#     {'id': 'GO:0009252', 'name': 'Peptidoglycan Biosyntheic Process'},
#     {'id': 'taxonomy:1314', 'name': 'Streptococcus pyogenes'},
#     {'id': 'MESH:D014069', 'name': 'Streptococcal tonsillitis'}]}},
#  {'graph': {'_id': 'DB09335_MESH_D011023_1',
#    'nodes': [{'id': 'MESH:C106856', 'name': 'alatrofloxacin'},
#     {'id': 'UniProtKB:P0C1U9', 'name': 'Topoisomeraze 4'},
#     {'id': 'UniProtKB:P20831', 'name': 'DNA gyrase'},
#     {'id': 'GO:0006260', 'name': 'Bacterial DNA replication'},
#     {'id': 'taxonomy:1280', 'name': 'Staphylococcus aureus'},
#     {'id': 'MESH:D011023', 'name': 'Staphylococcal pneumonia'}]}},
#  {'graph': {'_id': 'DB00479_MESH_D016920_1',
#    'nodes': [{'id': 'MESH:D000583', 'name': 'amikacin'},
#     {'id': 'UniProtKB:P0A7S3', 'name': '30S Ribosomal Subunit'},
#     {'id': 'GO:0006412', 'name': 'Bacterial Translation'},
#     {'id': 'taxonomy:2', 'name': 'Bacteria'},
#     {'id': 'MESH:D016920', 'name': 'Bacterial meningitis'}]}},
#  {'graph': {'_id': 'DB01234_MESH_D013717_1',
#    'nodes': [{'id': 'MESH:D003907', 'name': 'dexamethasone'},
#     {'id': 'UniProtKB:P04150', 'name': 'Glucocorticoid receptor'},
#     {'id': 'UniProtKB:P04083', 'name': 'Annexin A1'},
#     {'id': 'REACT:R-HSA-2162123', 'name': 'Prostaglandin Synthesis'},
#     {'id': 'GO:0006954', 'name': 'Inflammation'},
#     {'id': 'MESH:D013717', 'name': 'Tenosynovitis'}]}},
#  {'graph': {'_id': 'DB00438_MESH_D014552_1',
#    'nodes': [{'id': 'MESH:D002442', 'name': 'ceftazidime'},
#     {'id': 'TIGR:02074', 'name': 'Penicillin-binding protein 1A'},
#     {'id': 'GO:0009252', 'name': 'Bacterial Cell Wall Synthesis'},
#     {'id': 'taxonomy:562', 'name': 'Escherichia coli'},
#     {'id': 'MESH:D014552', 'name': 'Bacterial urinary infection'}]}},
#  {'graph': {'_id': 'DB06762_MESH_D006973_1',
#    'nodes': [{'id': 'MESH:D020110', 'name': 'pinacidil'},
#     {'id': 'UniProtKB:Q12791',
#      'name': 'Calcium-activated potassium channel subunit alpha-1'},
#     {'id': 'GO:0042311', 'name': 'Vasodilation'},
#     {'id': 'GO:0008217', 'name': 'Negative Regulation of Blood Pressure'},
#     {'id': 'MESH:D006973', 'name': 'Hypertension'}]}},
#  {'graph': {'_id': 'DB01263_MESH_D009181_1',
#    'nodes': [{'id': 'MESH:C101425', 'name': 'posaconazole'},
#     {'id': 'UniProtKB:P10613', 'name': 'sterol 14a-demethylase'},
#     {'id': 'MESH:D004875', 'name': 'ergosterol'},
#     {'id': 'GO:0009277', 'name': 'Fungal Cell Membrane'},
#     {'id': 'MESH:D009181', 'name': 'Fungal Infection'}]}},
#  {'graph': {'_id': 'DB08799_MESH_D012223_1',
#    'nodes': [{'id': 'MESH:D000865', 'name': 'antazoline'},
#     {'id': 'UniProtKB:P35367', 'name': 'histamine H1 Receptor'},
#     {'id': 'GO:0034776', 'name': 'histamine response'},
#     {'id': 'MESH:D012223', 'name': 'Vasomotor rhinitis'}]}},
#  {'graph': {'_id': 'DB01137_MESH_D011704_1',
#    'nodes': [{'id': 'MESH:D064704', 'name': 'levofloxacin'},
#     {'id': 'UniProtKB:P11388', 'name': 'DNA gyrase'},
#     {'id': 'GO:0006260', 'name': 'Bacterial DNA replication'},
#     {'id': 'taxonomy:562', 'name': 'E. coli'},
#     {'id': 'MESH:D011704', 'name': 'Pyelonephritis'}]}},
#  {'graph': {'_id': 'DB00814_MESH_D010146_1',
#    'nodes': [{'id': 'MESH:D000077239', 'name': 'meloxicam'},
#     {'id': 'UniProtKB:P35354', 'name': 'Prostaglandin synthhase 2'},
#     {'id': 'MESH:D011453', 'name': 'Prostaglandins'},
#     {'id': 'InterPro:IPR000265', 'name': 'Pain Receptors'},
#     {'id': 'MESH:D010146', 'name': 'Pain'}]}},
#  {'graph': {'_id': 'DB00393_MESH_D013345_1',
#    'nodes': [{'id': 'MESH:D009553', 'name': 'nimodipine'},
#     {'id': 'InterPro:IPR005446',
#      'name': 'voltage dependent l-type calcium channels'},
#     {'id': 'GO:0006939', 'name': 'Smooth muscle contraction'},
#     {'id': 'GO:0008217', 'name': 'Blood Pressure'},
#     {'id': 'MESH:D013345', 'name': 'Subarachnoid intracranial hemorrhage'}]}},
#  {'graph': {'_id': 'DB00326_MESH_D006996_1',
#    'nodes': [{'id': 'MESH:C007852', 'name': 'calcium glucoheptonate'},
#     {'id': 'MESH:D002118', 'name': 'Calcium Ion'},
#     {'id': 'MESH:D006996', 'name': 'hypocalcemia'}]}},
#  {'graph': {'_id': 'DB00588_MESH_D001991_1',
#    'nodes': [{'id': 'MESH:D000068298', 'name': 'fluticasone propionate'},
#     {'id': 'UniProtKB:P04150', 'name': 'Glucocorticoid receptor'},
#     {'id': 'UniProtKB:P47712', 'name': 'Phospholipase A2'},
#     {'id': 'UniProtKB:P22301', 'name': 'IL-10'},
#     {'id': 'GO:0006954', 'name': 'Inflammation'},
#     {'id': 'MESH:D001991', 'name': 'Bronchitis'}]}},
#  {'graph': {'_id': 'DB00623_MESH_D012559_1',
#    'nodes': [{'id': 'MESH:D005476', 'name': 'fluphenazine'},
#     {'id': 'UniProtKB:P14416', 'name': 'D(2) dopamine receptor'},
#     {'id': 'UniProtKB:P21728', 'name': 'dopaminaergeinc receptors'},
#     {'id': 'GO:0030252', 'name': 'growth hormone secretion'},
#     {'id': 'MESH:D010907', 'name': 'hypophyseal hormones'},
#     {'id': 'MESH:D012559', 'name': 'Schizophrenia'}]}},
#  {'graph': {'_id': 'DB00342_MESH_D017449_1',
#    'nodes': [{'id': 'MESH:D016593', 'name': 'terfenadine'},
#     {'id': 'UniProtKB:P35367', 'name': 'histamine H1 Receptor'},
#     {'id': 'HP:0000969', 'name': 'Edema'},
#     {'id': 'MESH:D017449', 'name': 'allergic skin disorders'}]}},
#  {'graph': {'_id': 'DB01048_MESH_D015658_1',
#    'nodes': [{'id': 'MESH:C106538', 'name': 'abacavir'},
#     {'id': 'MESH:C066928', 'name': 'carbovir triphosphate'},
#     {'id': 'UniProtKB:P04585', 'name': 'HIV-1 reverse transcriptase'},
#     {'id': 'GO:0039693', 'name': 'Viral DNA replication'},
#     {'id': 'MESH:D015658', 'name': 'HIV infection'}]}},
#  {'graph': {'_id': 'DB00717_MESH_D008595_1',
#    'nodes': [{'id': 'MESH:D009640', 'name': 'norethisterone'},
#     {'id': 'UniProtKB:P06401', 'name': 'progesterone receptor'},
#     {'id': 'UniProtKB:P01148', 'name': 'gonadotropin releasing hormone'},
#     {'id': 'GO:0032275', 'name': 'Luteinizing hormone secretion'},
#     {'id': 'MESH:D008595', 'name': 'Menorrhagia'}]}},
#  {'graph': {'_id': 'DB00246_MESH_D012559_1',
#    'nodes': [{'id': 'MESH:C092292', 'name': 'ziprasidone'},
#     {'id': 'UniProtKB:P14416', 'name': 'D(2) dopamine receptor'},
#     {'id': 'UniProtKB:P28223', 'name': '5-hydroxytryptamine receptor 2A'},
#     {'id': 'GO:0061527', 'name': 'dopamine secretion, neurotransmission'},
#     {'id': 'GO:0060096', 'name': 'serotonin secretion, neurotransmission'},
#     {'id': 'HP:0000738', 'name': 'Hallucinations'},
#     {'id': 'MESH:D012701', 'name': 'Serotonin'},
#     {'id': 'MESH:D012559', 'name': 'Schizophrenia'}]}},
#  {'graph': {'_id': 'DB00748_MESH_D003233_1',
#    'nodes': [{'id': 'MESH:C004649', 'name': 'carbinoxamine'},
#     {'id': 'UniProtKB:P35367', 'name': 'histamine H1 Receptor'},
#     {'id': 'GO:0034776', 'name': 'histamine response'},
#     {'id': 'MESH:D003233', 'name': 'seasonal allergic conjunctivitis'}]}},
#  {'graph': {'_id': 'DB00066_MESH_D016649_1',
#    'nodes': [{'id': 'MESH:D005640', 'name': 'follitropin'},
#     {'id': 'UniProtKB:P23945',
#      'name': 'Human follicle stimulating hormone receptor'},
#     {'id': 'GO:0030728', 'name': 'ovulation'},
#     {'id': 'MESH:D016649', 'name': 'primary ovarian failure'}]}},
#  {'graph': {'_id': 'DB01212_MESH_D006069_1',
#    'nodes': [{'id': 'MESH:D002443', 'name': 'Ceftriaxone'},
#     {'id': 'UniProtKB:P0A3M6', 'name': 'Penicillin-binding protein 2B'},
#     {'id': 'GO:0009252', 'name': 'peptidoglycan biosynthetic process'},
#     {'id': 'taxonomy:485', 'name': 'Neisseria gonorrhoeae'},
#     {'id': 'MESH:D006069', 'name': 'Gonorrhea'}]}},
#  {'graph': {'_id': 'DB02703_MESH_D000881_1',
#    'nodes': [{'id': 'MESH:D005672', 'name': 'fusidic acid'},
#     {'id': 'UniProtKB:Q81VT3', 'name': 'elongation factor g'},
#     {'id': 'GO:0006412', 'name': 'Bacterial Translation'},
#     {'id': 'taxonomy:1392', 'name': 'Bacillus anthracis'},
#     {'id': 'MESH:D000881', 'name': 'Anthrax'}]}},
#  {'graph': {'_id': 'DB00682_MESH_D011655_1',
#    'nodes': [{'id': 'MESH:D014859', 'name': 'warfarin'},
#     {'id': 'UniProtKB:Q9BQB6', 'name': 'vitamin k reductase'},
#     {'id': 'MESH:D014812', 'name': 'reduced vitamin k'},
#     {'id': 'GO:0007596', 'name': 'Coagulation factor Synthesis'},
#     {'id': 'MESH:D011655', 'name': 'Pulmonary embolism'}]}},
#  {'graph': {'_id': 'DB09046_MESH_D008060_1',
#    'nodes': [{'id': 'MESH:C415771', 'name': 'metreleptin'},
#     {'id': 'UniProtKB:P48357', 'name': 'leptin receptor'},
#     {'id': 'GO:0060612', 'name': 'adipogenesis'},
#     {'id': 'MESH:D008060', 'name': 'lipodystrophy'}]}},
#  {'graph': {'_id': 'DB01332_MESH_D007710_1',
#    'nodes': [{'id': 'MESH:D015296', 'name': 'ceftizoxime'},
#     {'id': 'TIGR:02074', 'name': 'Penicillin-binding protein 1A'},
#     {'id': 'GO:0009252', 'name': 'Bacterial Cell Wall Synthesis'},
#     {'id': 'taxonomy:573', 'name': 'Klebsiella pneumoniae'},
#     {'id': 'MESH:D007710', 'name': 'Klebsiella cystitis'}]}},
#  {'graph': {'_id': 'DB00455_MESH_D065631_1',
#    'nodes': [{'id': 'MESH:D017336', 'name': 'loratadine'},
#     {'id': 'UniProtKB:P35367', 'name': 'histamine H1 Receptor'},
#     {'id': 'GO:0034776', 'name': 'histamine response'},
#     {'id': 'MESH:D065631', 'name': 'Allergic Rhinitis'}]}},
#  {'graph': {'_id': 'DB00935_MESH_D015508_1',
#    'nodes': [{'id': 'MESH:D010109', 'name': 'oxymetazoline'},
#     {'id': 'UniProtKB:P35348', 'name': 'Alpha-1a adrenergic receptor'},
#     {'id': 'GO:0042310', 'name': 'Vasoconstriction'},
#     {'id': 'MESH:D015508', 'name': 'Nasal Congestion'}]}},
#  {'graph': {'_id': 'DB01174_MESH_D004827_1',
#    'nodes': [{'id': 'MESH:D010634', 'name': 'phenobarbital'},
#     {'id': 'InterPro:IPR006028', 'name': 'GABAA Receptors'},
#     {'id': 'GO:0099536', 'name': 'Synaptic Signaling'},
#     {'id': 'MESH:D004827', 'name': 'Epilepsy'}]}},
#  {'graph': {'_id': 'DB00281_MESH_D010146_1',
#    'nodes': [{'id': 'MESH:D008012', 'name': 'lidocaine'},
#     {'id': 'InterPro:IPR028809',
#      'name': 'Neuronal Voltage gated sodium channels'},
#     {'id': 'GO:0019233', 'name': 'Sensory perception of pain'},
#     {'id': 'MESH:D010146', 'name': 'Pain'}]}},
#  {'graph': {'_id': 'DB00476_MESH_D003865_1',
#    'nodes': [{'id': 'MESH:D000068736', 'name': 'duloxetine'},
#     {'id': 'UniProtKB:P31645',
#      'name': 'sodium dependent serotonin transporter'},
#     {'id': 'GO:0051610', 'name': 'Neuronal serotonin reuptake'},
#     {'id': 'MESH:D003865', 'name': 'major depressive disorder'}]}},
#  {'graph': {'_id': 'DB00366_MESH_D065631_1',
#    'nodes': [{'id': 'MESH:D004319', 'name': 'doxylamine'},
#     {'id': 'UniProtKB:P35367', 'name': 'histamine H1 Receptor'},
#     {'id': 'GO:0034776', 'name': 'histamine response'},
#     {'id': 'MESH:D065631', 'name': 'Allergic Rhinitis'}]}},
#  {'graph': {'_id': 'DB00650_MESH_D000749_1',
#    'nodes': [{'id': 'MESH:D002955', 'name': 'leucovorin'},
#     {'id': 'MESH:D005492', 'name': 'Folic Acid'},
#     {'id': 'MESH:D000749',
#      'name': 'Megaloblastic anemia (Methotrexate Treatment)'}]}},
#  {'graph': {'_id': 'DB01211_MESH_D015523_1',
#    'nodes': [{'id': 'MESH:D017291', 'name': 'clarithromycin'},
#     {'id': 'UniProtKB:P44350', 'name': '50S Ribosomal protein l-10'},
#     {'id': 'GO:0006412', 'name': 'Bacterial Translation'},
#     {'id': 'taxonomy:727', 'name': 'Haemophilus influenzae'},
#     {'id': 'MESH:D015523', 'name': 'Acute maxillary sinusitis'}]}},
#  {'graph': {'_id': 'DB00350_MESH_D000505_1',
#    'nodes': [{'id': 'MESH:D008914', 'name': 'minoxidil'},
#     {'id': 'CL:0000346', 'name': 'dermal papillary cells'},
#     {'id': 'REACT:R-HSA-5684996', 'name': 'ERK1/ERK2 pathway'},
#     {'id': 'UniProtKB:P48048',
#      'name': 'ATP-sensitive inward rectifier potassium channel 1'},
#     {'id': 'GO:0043066', 'name': 'negative regulation of apoptotic process'},
#     {'id': 'CL:0002559', 'name': 'hair follicle cell'},
#     {'id': 'GO:0060081', 'name': 'membrane hyperpolarization'},
#     {'id': 'GO:0070509', 'name': 'transmembrane calcium influx'},
#     {'id': 'GO:0042311', 'name': 'vasodilation'},
#     {'id': 'GO:0008015', 'name': 'blood circulation'},
#     {'id': 'GO:0042640', 'name': 'hair growth'},
#     {'id': 'MESH:D000505', 'name': 'androgenic alopecia'}]}},
#  {'graph': {'_id': 'DB00350_MESH_D006973_1',
#    'nodes': [{'id': 'MESH:D008914', 'name': 'Minoxidil'},
#     {'id': 'UniProtKB:P48048',
#      'name': 'ATP-sensitive inward rectifier potassium channel 1'},
#     {'id': 'GO:0060081', 'name': 'Membrane hyperpolarization'},
#     {'id': 'GO:0070509', 'name': 'Transmembrane calcium influx'},
#     {'id': 'GO:0006939', 'name': 'Smooth muscle contraction'},
#     {'id': 'GO:0045907', 'name': 'Vasoconstriction'},
#     {'id': 'MESH:D006973', 'name': 'Hypertension'}]}},
#  {'graph': {'_id': 'DB00203_MESH_D007172_1',
#    'nodes': [{'id': 'MESH:D000068677', 'name': 'sildenafil'},
#     {'id': 'UniProtKB:O76074', 'name': 'phosphodisterase type 5'},
#     {'id': 'MESH:D006152', 'name': 'cGMP'},
#     {'id': 'GO:0042311', 'name': 'Vasodilation'},
#     {'id': 'MESH:D007172', 'name': 'Erectile Disfunction'}]}},
#  {'graph': {'_id': 'DB01155_MESH_D018410_1',
#    'nodes': [{'id': 'MESH:D000077735', 'name': 'gemifloxacin'},
#     {'id': 'UniProtKB:P72525', 'name': 'Topoisomeraze 4'},
#     {'id': 'GO:0006260', 'name': 'Bacterial DNA replication'},
#     {'id': 'taxonomy:1313', 'name': 'Streptococcus pneumoniae'},
#     {'id': 'MESH:D018410', 'name': 'Bacterial pneumonia'}]}},
#  {'graph': {'_id': 'DB00443_MESH_D003424_1',
#    'nodes': [{'id': 'MESH:D001623', 'name': 'betamethasone'},
#     {'id': 'UniProtKB:P04150', 'name': 'Glucocorticoid receptor'},
#     {'id': 'UniProtKB:P47712', 'name': 'Phospholipase A2'},
#     {'id': 'GO:0006954', 'name': 'Inflammation'},
#     {'id': 'MESH:D003424', 'name': "Crohn's disease"}]}},
#  {'graph': {'_id': 'MESH_C106301_MESH_D003233_1',
#    'nodes': [{'id': 'MESH:C106301', 'name': 'tazanolast'},
#     {'id': 'GO:0002553', 'name': 'Histamine sections by Mast Cell'},
#     {'id': 'MESH:D003233', 'name': 'Allergic conjuctivitis'}]}},
#  {'graph': {'_id': 'DB00620_MESH_D003424_1',
#    'nodes': [{'id': 'MESH:D014221', 'name': 'triamcinolone diacetate'},
#     {'id': 'UniProtKB:P04150', 'name': 'Glucocorticoid receptor'},
#     {'id': 'UniProtKB:P47712', 'name': 'Phospholipase A2'},
#     {'id': 'GO:0006954', 'name': 'Inflammation'},
#     {'id': 'MESH:D003424', 'name': "Crohn's disease"}]}},
#  {'graph': {'_id': 'DB00996_MESH_D012148_1',
#    'nodes': [{'id': 'MESH:D000077206', 'name': 'Gabapentin'},
#     {'id': 'UniProtKB:P54289',
#      'name': 'Voltage-dependent calcium channel subunit alpha-2/delta-1'},
#     {'id': 'GO:0006936', 'name': 'muscle contraction'},
#     {'id': 'HP:0012531', 'name': 'Pain'},
#     {'id': 'MESH:D012148', 'name': 'Restless Legs Syndrome'}]}},
#  {'graph': {'_id': 'DB01598_MESH_D010538_1',
#    'nodes': [{'id': 'MESH:D015378', 'name': 'imipenem'},
#     {'id': 'UniProtKB:P0AD65', 'name': 'Penicillin-binding proteins'},
#     {'id': 'GO:0009252', 'name': 'Bacterial Cell Wall Synthesis'},
#     {'id': 'taxonomy:562', 'name': 'Escherichia coli'},
#     {'id': 'MESH:D010538', 'name': 'Peritonitis'}]}},
#  {'graph': {'_id': 'DB00860_MESH_D012507_1',
#    'nodes': [{'id': 'MESH:D011239', 'name': 'prednisolone'},
#     {'id': 'UniProtKB:P04150', 'name': 'Glucocorticoid receptor'},
#     {'id': 'UniProtKB:P04083', 'name': 'lipocortins'},
#     {'id': 'UniProtKB:P47712', 'name': 'phospholipase a2'},
#     {'id': 'GO:0006954', 'name': 'Inflammation signaling'},
#     {'id': 'MESH:D012507', 'name': 'Sarcoidosis'}]}},
#  {'graph': {'_id': 'DB09345_MESH_D010146_1',
#    'nodes': [{'id': 'MESH:C005548', 'name': 'pramocaine'},
#     {'id': 'InterPro:IPR028809',
#      'name': 'Neuronal Voltage gated sodium channels'},
#     {'id': 'GO:0019227', 'name': 'Neuronal Action Potential Transmission'},
#     {'id': 'MESH:D010146', 'name': 'Pain'}]}},
#  {'graph': {'_id': 'DB00994_MESH_D007634_1',
#    'nodes': [{'id': 'MESH:D009355', 'name': 'neomycin'},
#     {'id': 'CHEBI:18111', 'name': 'ribosomal RNA'},
#     {'id': 'GO:0006412', 'name': 'Translation'},
#     {'id': 'taxonomy:1280', 'name': 'Staphylococcus aureus'},
#     {'id': 'MESH:D007634', 'name': 'Keratitis'}]}},
#  {'graph': {'_id': 'DB00303_MESH_D018410_1',
#    'nodes': [{'id': 'MESH:D000077727', 'name': 'ertapenem'},
#     {'id': 'UniProtKB:P44469', 'name': 'Penicillin-binding proteins'},
#     {'id': 'GO:0009252', 'name': 'Bacterial Cell Wall Synthesis'},
#     {'id': 'taxonomy:727', 'name': 'Haemophilus influenzae'},
#     {'id': 'MESH:D018410', 'name': 'Bacterial pneumonia'}]}},
#  {'graph': {'_id': 'DB06786_MESH_D012871_1',
#    'nodes': [{'id': 'MESH:D006206', 'name': 'halcinonide'},
#     {'id': 'GO:0006954', 'name': 'inflammatory signalling'},
#     {'id': 'MESH:D012871', 'name': 'Dermatosis'}]}},
#  {'graph': {'_id': 'DB01100_MESH_D005879_1',
#    'nodes': [{'id': 'MESH:D010868', 'name': 'pimozide'},
#     {'id': 'UniProtKB:P14416', 'name': 'Dopamine D2 Receptor'},
#     {'id': 'GO:0014046', 'name': 'Dopamine Release'},
#     {'id': 'HP:0100033', 'name': 'tics'},
#     {'id': 'MESH:D005879', 'name': 'Tourette’s Disorder'}]}},
#  {'graph': {'_id': 'DB01527_MESH_D000856_1',
#    'nodes': [{'id': 'DB:DB01527', 'name': 'clortermine'},
#     {'id': 'MESH:D000856', 'name': 'Anorexia nervosa'}]}},
#  {'graph': {'_id': 'DB00367_MESH_D008595_1',
#    'nodes': [{'id': 'MESH:D016912', 'name': 'levonorgestrel'},
#     {'id': 'UniProtKB:P06401', 'name': 'progesterone receptor'},
#     {'id': 'UniProtKB:P01148', 'name': 'gonadotropin releasing hormone'},
#     {'id': 'GO:0032275', 'name': 'Luteinizing hormone secretion'},
#     {'id': 'MESH:D008595', 'name': 'Menorrhagia'}]}},
#  {'graph': {'_id': 'DB08908_MESH_D009103_1',
#    'nodes': [{'id': 'MESH:D000069462', 'name': 'dimethyl fumarate'},
#     {'id': 'UniProtKB:Q14145', 'name': 'Kelch-like ECH-associated protein 1'},
#     {'id': 'UniProtKB:Q16236', 'name': 'Nrf2'},
#     {'id': 'GO:0006979', 'name': 'Oxidative Stress'},
#     {'id': 'MESH:D009103', 'name': 'Multiple Sclerosis'}]}},
#  {'graph': {'_id': 'DB00638_MESH_D006943_1',
#    'nodes': [{'id': 'MESH:D007444', 'name': 'inulin'},
#     {'id': 'GO:0032099', 'name': 'negative regulation of appetite'},
#     {'id': 'MESH:D006943', 'name': 'Hyperglycemia'}]}},
#  {'graph': {'_id': 'DB00344_MESH_D003865_1',
#    'nodes': [{'id': 'MESH:D011530', 'name': 'protriptyline'},
#     {'id': 'UniProtKB:P23975',
#      'name': 'Sodium dependent noradrenaline transporter'},
#     {'id': 'MESH:D009638', 'name': 'noradrenaline'},
#     {'id': 'GO:0023041', 'name': 'Neuronal activation'},
#     {'id': 'MESH:D003865', 'name': 'Major depressive disorder'}]}},
#  {'graph': {'_id': 'DB13399_MESH_D006976_1',
#    'nodes': [{'id': 'MESH:C006208', 'name': 'terguride'},
#     {'id': 'UniProtKB:P41595', 'name': '5-Hydroxytryptamine receptor 2B'},
#     {'id': 'MESH:D006976', 'name': 'Pulmonary hypertension'}]}},
#  {'graph': {'_id': 'DB12770_MESH_D005764_1',
#    'nodes': [{'id': 'MESH:C076948', 'name': 'lafutidine'},
#     {'id': 'UniProtKB:P25021', 'name': 'Histamine H2 Receptor'},
#     {'id': 'GO:0001696', 'name': 'Gastric acid secretion'},
#     {'id': 'MESH:D005764', 'name': 'Gastroesophageal Reflux'}]}},
#  {'graph': {'_id': 'DB04938_MESH_D004414_1',
#    'nodes': [{'id': 'MESH:C119141', 'name': 'ospemifene'},
#     {'id': 'UniProtKB:P03372', 'name': 'estrogen receptor'},
#     {'id': 'MESH:D004967', 'name': 'estrogen'},
#     {'id': 'MESH:D059268', 'name': 'postmenopausal atrophic vaginitis'},
#     {'id': 'MESH:D004414', 'name': 'Dyspareunia'}]}},
#  {'graph': {'_id': 'DB00199_MESH_D008088_1',
#    'nodes': [{'id': 'MESH:D004917', 'name': 'erythromycin'},
#     {'id': 'MESH:D012338', 'name': '23S Ribosomal RNA'},
#     {'id': 'GO:0006412', 'name': 'Bacterial Translation'},
#     {'id': 'taxonomy:1637', 'name': 'Listeria spp.'},
#     {'id': 'MESH:D008088', 'name': 'Listeriosis'}]}},
#  {'graph': {'_id': 'DB02362_MESH_D010392_1',
#    'nodes': [{'id': 'MESH:D010129', 'name': 'aminobenzoic acid'},
#     {'id': 'MESH:D010392', 'name': 'Pemphigus'}]}},
#  {'graph': {'_id': 'DB01067_MESH_D006943_1',
#    'nodes': [{'id': 'MESH:D005913', 'name': 'glipizide'},
#     {'id': 'UniProtKB:Q09428',
#      'name': 'ATP-binding cassette sub-family C member 8'},
#     {'id': 'CL:0000169', 'name': 'Islet Cells'},
#     {'id': 'UniProtKB:P01308', 'name': 'insulin'},
#     {'id': 'MESH:D006943', 'name': 'Hyperglycemia'}]}},
#  {'graph': {'_id': 'DB12212_MESH_D013610_1',
#    'nodes': [{'id': 'MESH:C077049', 'name': 'landiolol'},
#     {'id': 'UniProtKB:P08588', 'name': 'Beta-1 adrenergic receptor'},
#     {'id': 'GO:0045823', 'name': 'positive regulation of heart contraction'},
#     {'id': 'MESH:D013610', 'name': 'Tachyarrhythmia'}]}},
#  {'graph': {'_id': 'DB01106_MESH_D003233_1',
#    'nodes': [{'id': 'MESH:C047340', 'name': 'levocabastine'},
#     {'id': 'UniProtKB:P35367', 'name': 'Histamine H1 receptor'},
#     {'id': 'GO:0004969', 'name': 'histamine receptor activity'},
#     {'id': 'MESH:D003233', 'name': 'Conjunctivitis, Allergic'}]}},
#  {'graph': {'_id': 'DB01418_MESH_D011655_1',
#    'nodes': [{'id': 'MESH:D000074', 'name': 'acenocoumarol'},
#     {'id': 'UniProtKB:Q9BQB6', 'name': 'vitamin k reductase'},
#     {'id': 'MESH:D014812', 'name': 'Reduced Vitamin k2 (vkH2)'},
#     {'id': 'GO:0007596', 'name': 'Clotting Factor Synthesis'},
#     {'id': 'MESH:D011655', 'name': 'Pulmonary Embolism'}]}},
#  {'graph': {'_id': 'DB14649_MESH_D009101_1',
#    'nodes': [{'id': 'MESH:C018038', 'name': 'dexamethasone acetate'},
#     {'id': 'UniProtKB:P04150', 'name': 'Glucocorticoid receptor'},
#     {'id': 'UniProtKB:P04083', 'name': 'annexin A1'},
#     {'id': 'UniProtKB:P47712', 'name': 'Phospholipase a2'},
#     {'id': 'GO:0019370', 'name': 'leukotriene biosysntesis'},
#     {'id': 'MESH:D009101', 'name': 'Multiple meyloma'}]}},
#  {'graph': {'_id': 'DB13676_MESH_D012559_1',
#    'nodes': [{'id': 'MESH:C046384', 'name': 'mosapramine'},
#     {'id': 'UniProtKB:P14416', 'name': 'Dopamine receptor D2'},
#     {'id': 'REACT:R-HSA-390651', 'name': 'Dopamine pathway'},
#     {'id': 'MESH:D012559', 'name': 'Schizophrenia'}]}},
#  {'graph': {'_id': 'DB00024_MESH_D013964_1',
#    'nodes': [{'id': 'MESH:D057073', 'name': 'thyrotropin alfa'},
#     {'id': 'UniProtKB:P16473', 'name': 'Thyrotropin receptor'},
#     {'id': 'UBERON:0002046', 'name': 'Thyroid'},
#     {'id': 'MESH:D013964', 'name': 'Thyroid cancer (Diagnostic)'}]}},
#  {'graph': {'_id': 'DB00524_MESH_D006973_1',
#    'nodes': [{'id': 'MESH:D008788', 'name': 'metolazone'},
#     {'id': 'UniProtKB:P55017', 'name': 'Solute carrier family 12 member 3'},
#     {'id': 'GO:0055078', 'name': 'Sodium Ion Homeostasis'},
#     {'id': 'MESH:D006973', 'name': 'Hypertension'}]}},
#  {'graph': {'_id': 'DB09142_MESH_D005705_1',
#    'nodes': [{'id': 'MESH:D012844', 'name': 'sincalide'},
#     {'id': 'GO:0032782', 'name': 'Bile acid secretion'},
#     {'id': 'MESH:D005705', 'name': 'Gallbladder Diseases (Diagnostic)'}]}},
#  {'graph': {'_id': 'DB12184_MESH_D003865_1',
#    'nodes': [{'id': 'MESH:C039979', 'name': 'gepirone'},
#     {'id': 'UniProtKB:P08908', 'name': '5-HT1a receptor (serotonin 1A)'},
#     {'id': 'GO:0050795', 'name': 'regulation of behavior'},
#     {'id': 'MESH:D003865', 'name': 'Major depressive disorder'}]}},
#  {'graph': {'_id': 'DB00193_MESH_D010146_1',
#    'nodes': [{'id': 'MESH:D014147', 'name': 'tramadol'},
#     {'id': 'UniProtKB:P35372', 'name': 'Mu-type opioid receptor'},
#     {'id': 'GO:0019233', 'name': 'sensory perception'},
#     {'id': 'MESH:D010146', 'name': 'Pain'}]}},
#  {'graph': {'_id': 'DB00347_MESH_D004832_1',
#    'nodes': [{'id': 'MESH:D014293', 'name': 'trimethadione'},
#     {'id': 'UniProtKB:O43497',
#      'name': 'voltage dependent T-type calcium channel subunit alpha-1G'},
#     {'id': 'GO:0007268', 'name': 'corticothalamic transmission'},
#     {'id': 'MESH:D004832', 'name': 'Absence seizure'}]}},
#  {'graph': {'_id': 'DB11901_MESH_D011471_1',
#    'nodes': [{'id': 'MESH:C572045', 'name': 'apalutamide'},
#     {'id': 'UniProtKB:P10275', 'name': 'androgen receptor'},
#     {'id': 'GO:0006351', 'name': 'gene transcription'},
#     {'id': 'GO:0008283', 'name': 'Cell proliferation'},
#     {'id': 'MESH:D011471', 'name': 'Nonmetastatic prostate cancer'}]}},
#  {'graph': {'_id': 'DB09105_MESH_D007014_1',
#    'nodes': [{'id': 'MESH:C570710', 'name': 'asfotase alfa'},
#     {'id': 'MESH:C107241', 'name': 'inorgainc pyrophosphate'},
#     {'id': 'GO:0030282', 'name': 'hydroxpatite crystal growth'},
#     {'id': 'HP:0004349', 'name': 'Reduced bone mineral density'},
#     {'id': 'MESH:D007014', 'name': 'Hypophosphatasia'}]}},
#  {'graph': {'_id': 'DB00357_MESH_D001943_1',
#    'nodes': [{'id': 'MESH:D000616', 'name': 'aminoglutethimide'},
#     {'id': 'UniProtKB:P11511', 'name': 'aromatase'},
#     {'id': 'MESH:D004967', 'name': 'estrogen'},
#     {'id': 'GO:0008283', 'name': 'Cell proliferation'},
#     {'id': 'MESH:D001943',
#      'name': 'Secondary malignant neoplasm of female breast'}]}},
#  {'graph': {'_id': 'DB06785_MESH_D010062_1',
#    'nodes': [{'id': 'MESH:C061018', 'name': 'ganirelix'},
#     {'id': 'UniProtKB:P30968', 'name': 'GnRH receptor'},
#     {'id': 'UBERON:0000007', 'name': 'pituitary gland'},
#     {'id': 'InterPro:IPR000476', 'name': 'gonadotropins'},
#     {'id': 'MESH:D010062', 'name': 'Ovulation induction'}]}},
#  {'graph': {'_id': 'DB00130_MESH_D012778_1',
#    'nodes': [{'id': 'MESH:D005973', 'name': 'glutamine'},
#     {'id': 'CL:0000584', 'name': 'enterocytes'},
#     {'id': 'GO:0050892', 'name': 'intestinal nutrient absorption'},
#     {'id': 'MESH:D012778', 'name': 'Short bowel syndrome'}]}},
#  {'graph': {'_id': 'DB01217_MESH_D001943_1',
#    'nodes': [{'id': 'MESH:D000077384', 'name': 'anastrozole'},
#     {'id': 'UniProtKB:P11511', 'name': 'aromatase'},
#     {'id': 'MESH:D004967', 'name': 'estrogen'},
#     {'id': 'GO:0030284', 'name': 'esterogne receptor activity'},
#     {'id': 'MESH:D001943',
#      'name': 'Hormone receptor positive malignant neoplasm of breast'}]}},
#  {'graph': {'_id': 'DB03404_MESH_D017118_1',
#    'nodes': [{'id': 'MESH:D006427', 'name': 'hemin'},
#     {'id': 'UniProtKB:P13196', 'name': 'Aminolevulinic acid synthase'},
#     {'id': 'REACT:R-HSA-189451', 'name': 'Heme biosynthesis'},
#     {'id': 'MESH:D011162', 'name': 'porpholobilinogen'},
#     {'id': 'MESH:D017118', 'name': 'Acute intermittent porphyria'}]}},
#  {'graph': {'_id': 'DB09166_MESH_D001008_1',
#    'nodes': [{'id': 'MESH:C044610', 'name': 'etizolam'},
#     {'id': 'UniProtKB:P14867', 'name': 'GABA-A receptor alpha 1'},
#     {'id': 'GO:0022851', 'name': 'GABA-A receptor activity'},
#     {'id': 'MESH:D001008', 'name': 'Anxiety disorders'}]}},
#  {'graph': {'_id': 'DB07565_MESH_D014435_1',
#    'nodes': [{'id': 'MESH:C026016', 'name': 'chloramphenicol succinate'},
#     {'id': 'UniProtKB:P0A298', 'name': '50S ribosomal subunit'},
#     {'id': 'GO:0006412', 'name': 'Bacterial Protein Synthesis'},
#     {'id': 'taxonomy:90370', 'name': 'Salmonella typhi'},
#     {'id': 'MESH:D014435', 'name': 'Typhoid fever'}]}},
#  {'graph': {'_id': 'DB11100_MESH_D012628_1',
#    'nodes': [{'id': 'MESH:D000481', 'name': 'allantoin'},
#     {'id': 'GO:0042060', 'name': 'fibroblast proliferation'},
#     {'id': 'MESH:D012628', 'name': 'Seborrheic dermatitis'}]}},
#  {'graph': {'_id': 'DB00016_MESH_D000740_1',
#    'nodes': [{'id': 'MESH:C555712', 'name': 'epoetin theta'},
#     {'id': 'UniProtKB:P19235', 'name': 'erythropoietin receptor'},
#     {'id': 'GO:0030218', 'name': 'erythrocyte differentiation'},
#     {'id': 'CL:0000232', 'name': 'erythrocytes'},
#     {'id': 'MESH:D000740', 'name': 'Anemia'}]}},
#  {'graph': {'_id': 'DB00795_MESH_D003093_1',
#    'nodes': [{'id': 'MESH:D012460', 'name': 'sulfasalazine'},
#     {'id': 'UniProtKB:P09917', 'name': 'Arachidonate 5-lipoxygenase'},
#     {'id': 'GO:0019370', 'name': 'leukotriene biosynthesis'},
#     {'id': 'GO:0006954', 'name': 'inflammatory response'},
#     {'id': 'MESH:D003093', 'name': 'Ulcerative Colitis'}]}},
#  {'graph': {'_id': 'DB00529_MESH_D017726_1',
#    'nodes': [{'id': 'MESH:D017245', 'name': 'foscarnet'},
#     {'id': 'UniProtKB:P08546', 'name': 'viral DNA Polymerase'},
#     {'id': 'GO:0039693', 'name': 'viral DNA replication'},
#     {'id': 'taxonomy:10358', 'name': 'Cytomegalovirus'},
#     {'id': 'MESH:D017726', 'name': 'Cytomegalovirus Retinitis'}]}},
#  {'graph': {'_id': 'DB00878_MESH_D010518_1',
#    'nodes': [{'id': 'MESH:D002710', 'name': 'chlorhexidine'},
#     {'id': 'GO:0009274', 'name': 'Bacterial Cell Wall'},
#     {'id': 'taxonomy:837', 'name': 'Porphyromonas gingivalis'},
#     {'id': 'MESH:D010518', 'name': 'periodontitis'}]}},
#  {'graph': {'_id': 'DB00059_MESH_D054198_1',
#    'nodes': [{'id': 'MESH:C042705', 'name': 'pegaspargase'},
#     {'id': 'MESH:D001216', 'name': 'extracellular asparagine'},
#     {'id': 'GO:0008283', 'name': 'cellular proliferation'},
#     {'id': 'MESH:D054198', 'name': 'Acute lymphoblastic leukemia'}]}},
#  {'graph': {'_id': 'DB01201_MESH_D014397_1',
#    'nodes': [{'id': 'MESH:C018421', 'name': 'rifapentine'},
#     {'id': 'UniProtKB:P9WGY7',
#      'name': 'DNA-directed RNA polymerase subunit beta'},
#     {'id': 'GO:0032774', 'name': 'RNA synthesis'},
#     {'id': 'taxonomy:1773', 'name': 'Mycobacterium tuberculosis infection'},
#     {'id': 'MESH:D014397', 'name': 'Pulmonary tuberculosis'}]}},
#  {'graph': {'_id': 'DB11152_MESH_D003218_1',
#    'nodes': [{'id': 'MESH:D014238', 'name': 'Trichloroacetic Acid'},
#     {'id': 'GO:0006915', 'name': 'apoptotic process'},
#     {'id': 'taxonomy:10566', 'name': 'Human papillomavirus'},
#     {'id': 'MESH:D003218', 'name': 'Condylomata Acuminata'}]}},
#  {'graph': {'_id': 'DB12131_MESH_D003704_1',
#    'nodes': [{'id': 'MESH:C013983', 'name': 'vinpocetine'},
#     {'id': 'UniProtKB:P54750',
#      'name': "Calcium/calmodulin-dependent 3',5'-cyclic nucleotide phosphodiesterase 1A"},
#     {'id': 'GO:0043025', 'name': 'Neuronal Cell Body'},
#     {'id': 'MESH:D003704', 'name': 'Dementia'}]}},
#  {'graph': {'_id': 'DB13142_MESH_D006996_1',
#    'nodes': [{'id': 'MESH:C042131', 'name': 'calcium glubionate'},
#     {'id': 'MESH:D002118', 'name': 'Calcium Ion'},
#     {'id': 'MESH:D006996', 'name': 'Hypocalcemia'}]}},
#  {'graph': {'_id': 'DB01437_MESH_D007319_1',
#    'nodes': [{'id': 'MESH:D005984', 'name': 'glutethimide'},
#     {'id': 'UniProtKB:P14867',
#      'name': 'Gamma-aminobutyric acid receptor subunit alpha-1'},
#     {'id': 'GO:1904862', 'name': 'inhibitory synapse assembly'},
#     {'id': 'MESH:D007319', 'name': 'Insomnia'}]}},
#  {'graph': {'_id': 'DB01213_MESH_D000138_1',
#    'nodes': [{'id': 'MESH:D000077604', 'name': 'fomepizole'},
#     {'id': 'UniProtKB:P07327', 'name': 'Alcohol dehydrogenase 1A'},
#     {'id': 'REACT:R-HSA-71384', 'name': 'Ethanol oxidation'},
#     {'id': 'MESH:C030544', 'name': 'formic acid'},
#     {'id': 'MESH:D000138', 'name': 'Methanol poisoning'}]}},
#  {'graph': {'_id': 'DB04931_MESH_D046351_1',
#    'nodes': [{'id': 'MESH:C534526', 'name': 'Afamelanotide'},
#     {'id': 'UniProtKB:Q01726',
#      'name': 'Melanocyte-stimulating hormone receptor'},
#     {'id': 'GO:0042438', 'name': 'Melanogenesis'},
#     {'id': 'MESH:C041877', 'name': 'Eumelanin'},
#     {'id': 'GO:0009650', 'name': 'UV protection'},
#     {'id': 'MESH:D046351', 'name': 'Erythropoietic protoporphyria'}]}},
#  {'graph': {'_id': 'DB11693_MESH_D014605_1',
#    'nodes': [{'id': 'MESH:C484071', 'name': 'voclosporin'},
#     {'id': 'UniProtKB:P63098', 'name': 'Calcineurin subunit B type 1'},
#     {'id': 'UniProtKB:O95644',
#      'name': 'Nuclear factor of activated T-cells, cytoplasmic 1'},
#     {'id': 'UniProtKB:P60568', 'name': 'interleukin 2'},
#     {'id': 'CL:0000084', 'name': 'T-Cell'},
#     {'id': 'MESH:D014605', 'name': 'Noninfectious Uveitis'}]}},
#  {'graph': {'_id': 'DB11254_MESH_D014010_1',
#    'nodes': [{'id': 'DB:DB11254', 'name': 'acrisorcin'},
#     {'id': 'MESH:D014010', 'name': 'Pityriasis versicolor'}]}},
#  {'graph': {'_id': 'DB00602_MESH_D009855_1',
#    'nodes': [{'id': 'MESH:D007559', 'name': 'ivermectin'},
#     {'id': 'InterPro:IPR015680', 'name': 'glutimate-gated chloride channels'},
#     {'id': 'CHEBI:17996', 'name': 'chloride ion'},
#     {'id': 'GO:0060081', 'name': 'membrane hyperpolarization'},
#     {'id': 'MESH:D010243', 'name': 'Paralysis'},
#     {'id': 'taxonomy:6282', 'name': 'Onchocerca volvulus'},
#     {'id': 'MESH:D009855', 'name': 'Onchocerciasis'}]}},
#  {'graph': {'_id': 'DB09065_MESH_D015658_1',
#    'nodes': [{'id': 'MESH:D000069547', 'name': 'cobicistat'},
#     {'id': 'UniProtKB:Q9HB55', 'name': 'cytochrome P450 3A (CYP3A) isoforms'},
#     {'id': 'MESH:D000069446', 'name': 'atazanavir'},
#     {'id': 'UniProtKB:P04585', 'name': 'Gag-Pol polyprotein'},
#     {'id': 'GO:0019068', 'name': 'Viral Assembly'},
#     {'id': 'MESH:D015658', 'name': 'HIV infection'}]}},
#  {'graph': {'_id': 'DB11945_MESH_D015266_1',
#    'nodes': [{'id': 'MESH:C000609138', 'name': 'avelumab'},
#     {'id': 'UniProtKB:Q9NZQ7', 'name': 'Programmed cell death 1 ligand 1'},
#     {'id': 'GO:0036037', 'name': 'Cytotoxic T-Cell activity'},
#     {'id': 'GO:0008283', 'name': 'Cell proliferation'},
#     {'id': 'MESH:D015266', 'name': 'Merkel cell carcinoma'}]}},
#  {'graph': {'_id': 'DB00253_MESH_D014605_1',
#    'nodes': [{'id': 'MESH:C100283', 'name': 'medrysone'},
#     {'id': 'UniProtKB:P04150', 'name': 'Glucocorticoid receptor'},
#     {'id': 'UniProtKB:P04083', 'name': 'Annexin A1'},
#     {'id': 'UniProtKB:P47712', 'name': 'Cytosolic phospholipase A2'},
#     {'id': 'UniProtKB:P35354', 'name': 'Prostaglandin G/H synthase 2'},
#     {'id': 'MESH:D011453', 'name': 'Prostaglandins'},
#     {'id': 'GO:0006954', 'name': 'inflammatory response'},
#     {'id': 'MESH:D014605', 'name': 'Uveitis'}]}},
#  {'graph': {'_id': 'DB00253_MESH_D003320_1',
#    'nodes': [{'id': 'MESH:C100283', 'name': 'medrysone'},
#     {'id': 'MESH:D003320', 'name': 'Corneal ulcer'}]}},
#  {'graph': {'_id': 'DB00253_MESH_D003233_1',
#    'nodes': [{'id': 'MESH:C100283', 'name': 'medrysone'},
#     {'id': 'UniProtKB:P04150', 'name': 'Glucocorticoid receptor'},
#     {'id': 'UniProtKB:P04083', 'name': 'Annexin A1'},
#     {'id': 'UniProtKB:P47712', 'name': 'Cytosolic phospholipase A2'},
#     {'id': 'UniProtKB:P35354', 'name': 'Prostaglandin G/H synthase 2'},
#     {'id': 'MESH:D011453', 'name': 'Prostaglandins'},
#     {'id': 'GO:0006954', 'name': 'inflammatory response'},
#     {'id': 'MESH:D003233', 'name': 'Allergic conjunctivitis'}]}},
#  {'graph': {'_id': 'DB00253_MESH_D012393_1',
#    'nodes': [{'id': 'MESH:C100283', 'name': 'medrysone'},
#     {'id': 'MESH:D012393', 'name': 'Rosacea'}]}},
#  {'graph': {'_id': 'DB00253_MESH_D007500_1',
#    'nodes': [{'id': 'MESH:C100283', 'name': 'medrysone'},
#     {'id': 'UniProtKB:P04150', 'name': 'Glucocorticoid receptor'},
#     {'id': 'UniProtKB:P04083', 'name': 'Annexin A1'},
#     {'id': 'UniProtKB:P47712', 'name': 'Cytosolic phospholipase A2'},
#     {'id': 'UniProtKB:P35354', 'name': 'Prostaglandin G/H synthase 2'},
#     {'id': 'MESH:D011453', 'name': 'Prostaglandins'},
#     {'id': 'GO:0006954', 'name': 'inflammatory response'},
#     {'id': 'MESH:D007500', 'name': 'Iritis'}]}},
#  {'graph': {'_id': 'DB00253_MESH_D015863_1',
#    'nodes': [{'id': 'MESH:C100283', 'name': 'medrysone'},
#     {'id': 'UniProtKB:P04150', 'name': 'Glucocorticoid receptor'},
#     {'id': 'UniProtKB:P04083', 'name': 'Annexin A1'},
#     {'id': 'UniProtKB:P47712', 'name': 'Cytosolic phospholipase A2'},
#     {'id': 'UniProtKB:P35354', 'name': 'Prostaglandin G/H synthase 2'},
#     {'id': 'MESH:D011453', 'name': 'Prostaglandins'},
#     {'id': 'GO:0006954', 'name': 'inflammatory response'},
#     {'id': 'MESH:D015863', 'name': 'Iridocyclitis'}]}},
#  {'graph': {'_id': 'DB00630_MESH_D015663_1',
#    'nodes': [{'id': 'MESH:D019386', 'name': 'alendronic acid'},
#     {'id': 'GO:0006915', 'name': 'apoptotic process'},
#     {'id': 'CL:0000092', 'name': 'Osteoclast'},
#     {'id': 'GO:0045453', 'name': 'Bone Resorption'},
#     {'id': 'MESH:D015663', 'name': 'Postmenopausal osteoporosis'}]}},
#  {'graph': {'_id': 'DB00630_MESH_D010001_1',
#    'nodes': [{'id': 'MESH:D019386', 'name': 'alendronic acid'},
#     {'id': 'GO:0006915', 'name': 'apoptotic process'},
#     {'id': 'CL:0000092', 'name': 'Osteoclast'},
#     {'id': 'GO:0045453', 'name': 'Bone Resorption'},
#     {'id': 'MESH:D010001', 'name': 'Osteitis deformans'}]}},
#  {'graph': {'_id': 'DB00861_MESH_D010003_1',
#    'nodes': [{'id': 'MESH:D004061', 'name': 'diflunisal'},
#     {'id': 'UniProtKB:P23219', 'name': 'Prostaglandin G/H synthase 1'},
#     {'id': 'UniProtKB:P35354', 'name': 'Prostaglandin G/H synthase 2'},
#     {'id': 'MESH:D011453', 'name': 'Prostaglandins'},
#     {'id': 'GO:0006954', 'name': 'inflammatory response'},
#     {'id': 'MESH:D010146', 'name': 'Pain'},
#     {'id': 'MESH:D010003', 'name': 'Osteoarthritis'}]}},
#  {'graph': {'_id': 'DB00861_MESH_D001172_1',
#    'nodes': [{'id': 'MESH:D004061', 'name': 'diflunisal'},
#     {'id': 'UniProtKB:P23219', 'name': 'Prostaglandin G/H synthase 1'},
#     {'id': 'UniProtKB:P35354', 'name': 'Prostaglandin G/H synthase 2'},
#     {'id': 'MESH:D011453', 'name': 'Prostaglandins'},
#     {'id': 'GO:0006954', 'name': 'inflammatory response'},
#     {'id': 'MESH:D010146', 'name': 'Pain'},
#     {'id': 'MESH:D001172', 'name': 'Rheumatoid arthritis'}]}},
#  {'graph': {'_id': 'DB00861_MESH_D010146_1',
#    'nodes': [{'id': 'MESH:D004061', 'name': 'diflunisal'},
#     {'id': 'UniProtKB:P23219', 'name': 'Prostaglandin G/H synthase 1'},
#     {'id': 'UniProtKB:P35354', 'name': 'Prostaglandin G/H synthase 2'},
#     {'id': 'MESH:D011453', 'name': 'Prostaglandins'},
#     {'id': 'GO:0006954', 'name': 'inflammatory response'},
#     {'id': 'MESH:D010146', 'name': 'Pain'}]}},
#  {'graph': {'_id': 'DB00861_MESH_D059350_1',
#    'nodes': [{'id': 'MESH:D004061', 'name': 'diflunisal'},
#     {'id': 'UniProtKB:P23219', 'name': 'Prostaglandin G/H synthase 1'},
#     {'id': 'UniProtKB:P35354', 'name': 'Prostaglandin G/H synthase 2'},
#     {'id': 'MESH:D011453', 'name': 'Prostaglandins'},
#     {'id': 'GO:0006954', 'name': 'inflammatory response'},
#     {'id': 'MESH:D059350', 'name': 'Chronic pain'}]}},
#  {'graph': {'_id': 'DB01324_MESH_D006973_1',
#    'nodes': [{'id': 'MESH:D011139', 'name': 'polythiazide'},
#     {'id': 'UniProtKB:P55017', 'name': 'Solute carrier family 12 member 3'},
#     {'id': 'GO:0070294', 'name': 'renal sodium ion absorption'},
#     {'id': 'GO:0003092', 'name': 'renal water retention'},
#     {'id': 'MESH:D006973', 'name': 'Hypertensive disorder'}]}},
#  {'graph': {'_id': 'DB06691_MESH_D003139_1',
#    'nodes': [{'id': 'MESH:D011738', 'name': 'mepyramine'},
#     {'id': 'UniProtKB:P35367', 'name': 'Histamine H1 receptor'},
#     {'id': 'MESH:D006632', 'name': 'Histamine'},
#     {'id': 'UniProtKB:P50148',
#      'name': 'Guanine nucleotide-binding protein G(q) subunit alpha'},
#     {'id': 'UniProtKB:P19838',
#      'name': 'Nuclear factor NF-kappa-B p105 subunit'},
#     {'id': 'GO:0006954', 'name': 'inflammatory response'},
#     {'id': 'taxonomy:10239', 'name': 'Viruses'},
#     {'id': 'MESH:D003139', 'name': 'Common cold'}]}},
#  {'graph': {'_id': 'DB06691_MESH_D003233_1',
#    'nodes': [{'id': 'MESH:D011738', 'name': 'mepyramine'},
#     {'id': 'UniProtKB:P35367', 'name': 'Histamine H1 receptor'},
#     {'id': 'MESH:D006632', 'name': 'Histamine'},
#     {'id': 'UniProtKB:P50148',
#      'name': 'Guanine nucleotide-binding protein G(q) subunit alpha'},
#     {'id': 'UniProtKB:P19838',
#      'name': 'Nuclear factor NF-kappa-B p105 subunit'},
#     {'id': 'GO:0006954', 'name': 'inflammatory response'},
#     {'id': 'HP:0000969', 'name': 'Edema'},
#     {'id': 'MESH:D003233', 'name': 'Allergic conjunctivitis'}]}},
#  {'graph': {'_id': 'DB06691_MESH_D006255_1',
#    'nodes': [{'id': 'MESH:D011738', 'name': 'mepyramine'},
#     {'id': 'UniProtKB:P35367', 'name': 'Histamine H1 receptor'},
#     {'id': 'MESH:D006632', 'name': 'Histamine'},
#     {'id': 'UniProtKB:P50148',
#      'name': 'Guanine nucleotide-binding protein G(q) subunit alpha'},
#     {'id': 'UniProtKB:P19838',
#      'name': 'Nuclear factor NF-kappa-B p105 subunit'},
#     {'id': 'GO:0006954', 'name': 'inflammatory response'},
#     {'id': 'UBERON:0000004', 'name': 'Nose'},
#     {'id': 'MESH:D006255', 'name': 'Seasonal allergic rhinitis'}]}},
#  {'graph': {'_id': 'DB06691_MESH_D012912_1',
#    'nodes': [{'id': 'MESH:D011738', 'name': 'mepyramine'},
#     {'id': 'UniProtKB:P35367', 'name': 'Histamine H1 receptor'},
#     {'id': 'MESH:D006632', 'name': 'Histamine'},
#     {'id': 'CL:0000540', 'name': 'neuron'},
#     {'id': 'UBERON:0000004', 'name': 'Nose'},
#     {'id': 'UBERON:0001645', 'name': 'trigeminal nerve'},
#     {'id': 'MESH:D012912', 'name': 'Sneezing'}]}},
#  {'graph': {'_id': 'DB06691_MESH_D065631_1',
#    'nodes': [{'id': 'MESH:D011738', 'name': 'mepyramine'},
#     {'id': 'UniProtKB:P35367', 'name': 'Histamine H1 receptor'},
#     {'id': 'MESH:D006632', 'name': 'Histamine'},
#     {'id': 'UniProtKB:P50148',
#      'name': 'Guanine nucleotide-binding protein G(q) subunit alpha'},
#     {'id': 'UniProtKB:P19838',
#      'name': 'Nuclear factor NF-kappa-B p105 subunit'},
#     {'id': 'GO:0006954', 'name': 'inflammatory response'},
#     {'id': 'UBERON:0000004', 'name': 'Nose'},
#     {'id': 'MESH:D065631', 'name': 'Allergic rhinitis'}]}},
#  {'graph': {'_id': 'DB06691_MESH_D004412_1',
#    'nodes': [{'id': 'MESH:D011738', 'name': 'mepyramine'},
#     {'id': 'UniProtKB:P35367', 'name': 'Histamine H1 receptor'},
#     {'id': 'CL:0000198', 'name': 'Nociceptors'},
#     {'id': 'GO:0019233', 'name': 'sensory perception of pain'},
#     {'id': 'MESH:D004412', 'name': 'Dysmenorrhea'}]}},
#  {'graph': {'_id': 'DB06691_MESH_D012223_1',
#    'nodes': [{'id': 'MESH:D011738', 'name': 'mepyramine'},
#     {'id': 'UniProtKB:P35367', 'name': 'Histamine H1 receptor'},
#     {'id': 'MESH:D006632', 'name': 'Histamine'},
#     {'id': 'MESH:D013373', 'name': 'Substance P'},
#     {'id': 'MESH:D020078', 'name': 'Neurogenic Inflammation'},
#     {'id': 'MESH:D012223', 'name': 'Vasomotor rhinitis'}]}},
#  {'graph': {'_id': 'DB06691_MESH_D014581_1',
#    'nodes': [{'id': 'MESH:D011738', 'name': 'mepyramine'},
#     {'id': 'UniProtKB:P35367', 'name': 'Histamine H1 receptor'},
#     {'id': 'MESH:D006632', 'name': 'Histamine'},
#     {'id': 'GO:0043117',
#      'name': 'positive regulation of vascular permeability'},
#     {'id': 'HP:0000969', 'name': 'Edema'},
#     {'id': 'MESH:D014581', 'name': 'Urticaria'}]}},
#  {'graph': {'_id': 'DB06691_MESH_D011537_1',
#    'nodes': [{'id': 'MESH:D011738', 'name': 'mepyramine'},
#     {'id': 'UniProtKB:P35367', 'name': 'Histamine H1 receptor'},
#     {'id': 'MESH:D006632', 'name': 'Histamine'},
#     {'id': 'UniProtKB:Q8NER1',
#      'name': 'Transient receptor potential cation channel subfamily V member 1'},
#     {'id': 'CL:0000197', 'name': 'Sensory Receptor Cell'},
#     {'id': 'MESH:D011537', 'name': 'Itching of skin'}]}},
#  {'graph': {'_id': 'DB08822_MESH_D006973_1',
#    'nodes': [{'id': 'DB:DB08822', 'name': 'azilsartan medoxomil'},
#     {'id': 'UniProtKB:P30556', 'name': 'Type-1 angiotensin II receptor'},
#     {'id': 'MESH:D000804', 'name': 'Angiotensin II'},
#     {'id': 'MESH:D014661', 'name': 'Vasoconstriction'},
#     {'id': 'MESH:D006973', 'name': 'Hypertensive disorder'}]}},
#  {'graph': {'_id': 'DB08880_MESH_D009103_1',
#    'nodes': [{'id': 'MESH:C527525', 'name': 'teriflunomide'},
#     {'id': 'UniProtKB:Q02127',
#      'name': 'Dihydroorotate dehydrogenase (quinone), mitochondrial'},
#     {'id': 'GO:0006221', 'name': 'pyrimidine nucleotide biosynthetic process'},
#     {'id': 'GO:0050671',
#      'name': 'positive regulation of lymphocyte proliferation'},
#     {'id': 'UBERON:0001017', 'name': 'central nervous system'},
#     {'id': 'GO:0006954', 'name': 'inflammatory response'},
#     {'id': 'GO:0048681', 'name': 'negative regulation of axon regeneration'},
#     {'id': 'MESH:D009103', 'name': 'Multiple sclerosis'}]}},
#  {'graph': {'_id': 'DB09310_MESH_C567691_1',
# ...
#     {'id': 'MESH:D020078', 'name': 'Neurogenic Inflammation'},
#     {'id': 'MESH:D012223', 'name': 'Vasomotor rhinitis'}]}},
#  {'graph': {'_id': 'DB00405_MESH_D003233_1',
#    'nodes': [{'id': 'MESH:C015121', 'name': 'Dexbrompheniramine'},
#     {'id': 'UniProtKB:P35367', 'name': 'Histamine H1 receptor'},
#     {'id': 'MESH:D006632', 'name': 'Histamine'},
#     {'id': 'UBERON:0035501', 'name': 'Free nerve ending'},
#     {'id': 'GO:0070075', 'name': 'Tear secretion'},
#     {'id': 'MESH:D003233', 'name': 'Allergic conjunctivitis'}]}},
#  {'graph': {'_id': 'DB00751_MESH_D003233_1',
#    'nodes': [{'id': 'MESH:C053090', 'name': 'Epinastine'},
#     {'id': 'UniProtKB:P35367', 'name': 'Histamine H1 receptor'},
#     {'id': 'UniProtKB:P25021', 'name': 'Histamine H2 receptor'},
#     {'id': 'GO:0043303', 'name': 'Mast cell degranulation'},
#     {'id': 'MESH:D006632', 'name': 'Histamine'},
#     {'id': 'UBERON:0035501', 'name': 'Free nerve ending'},
#     {'id': 'GO:0070075', 'name': 'Tear secretion'},
#     {'id': 'MESH:D003233', 'name': 'Allergic conjunctivitis'}]}},
#  {'graph': {'_id': 'DB00915_MESH_D001480_1',
#    'nodes': [{'id': 'MESH:D000547', 'name': 'Amantadine'},
#     {'id': 'UniProtKB:P14416', 'name': 'D(2) dopamine receptor'},
#     {'id': 'MESH:D004298', 'name': 'Dopamine'},
#     {'id': 'GO:0061527', 'name': 'Dopamine secretion, neurotransmission'},
#     {'id': 'MESH:D001480', 'name': 'Basal Ganglia Diseases'}]}},
#  {'graph': {'_id': 'DB00915_MESH_D010300_1',
#    'nodes': [{'id': 'MESH:D000547', 'name': 'Amantadine'},
#     {'id': 'UniProtKB:P14416', 'name': 'D(2) dopamine receptor'},
#     {'id': 'MESH:D004298', 'name': 'Dopamine'},
#     {'id': 'GO:0061527', 'name': 'Dopamine secretion, neurotransmission'},
#     {'id': 'UBERON:0002038', 'name': 'Substantia nigra'},
#     {'id': 'MESH:D010300', 'name': "Parkinson's disease"}]}},
#  {'graph': {'_id': 'DB00915_MESH_D020734_1',
#    'nodes': [{'id': 'MESH:D000547', 'name': 'Amantadine'},
#     {'id': 'UniProtKB:P14416', 'name': 'D(2) dopamine receptor'},
#     {'id': 'MESH:D004298', 'name': 'Dopamine'},
#     {'id': 'GO:0061527', 'name': 'Dopamine secretion, neurotransmission'},
#     {'id': 'MESH:D020734', 'name': 'Parkinsonian Disorders'}]}},
#  {'graph': {'_id': 'DB00915_MESH_D010301_1',
#    'nodes': [{'id': 'MESH:D000547', 'name': 'Amantadine'},
#     {'id': 'UniProtKB:P14416', 'name': 'D(2) dopamine receptor'},
#     {'id': 'MESH:D004298', 'name': 'Dopamine'},
#     {'id': 'GO:0061527', 'name': 'Dopamine secretion, neurotransmission'},
#     {'id': 'UBERON:0002038', 'name': 'Substantia nigra'},
#     {'id': 'MESH:D010301', 'name': 'Postencephalitic parkinsonism'}]}},
#  {'graph': {'_id': 'DB01084_MESH_D014581_1',
#    'nodes': [{'id': 'MESH:C043345', 'name': 'Emedastine'},
#     {'id': 'UniProtKB:P35367', 'name': 'Histamine H1 receptor'},
#     {'id': 'GO:0071420', 'name': 'Cellular response to histamine'},
#     {'id': 'GO:0006954', 'name': 'Inflammatory response'},
#     {'id': 'MESH:D014581', 'name': 'Urticaria'}]}},
#  {'graph': {'_id': 'DB01084_MESH_D011537_1',
#    'nodes': [{'id': 'MESH:C043345', 'name': 'Emedastine'},
#     {'id': 'UniProtKB:P35367', 'name': 'Histamine H1 receptor'},
#     {'id': 'MESH:D006632', 'name': 'Histamine'},
#     {'id': 'UniProtKB:Q8NER1',
#      'name': 'Transient receptor potential cation channel subfamily V member 1'},
#     {'id': 'CL:0000197', 'name': 'Sensory Receptor Cell'},
#     {'id': 'MESH:D011537', 'name': 'Itching of skin'}]}},
#  {'graph': {'_id': 'DB01084_MESH_D003233_1',
#    'nodes': [{'id': 'MESH:C043345', 'name': 'Emedastine'},
#     {'id': 'UniProtKB:P35367', 'name': 'Histamine H1 receptor'},
#     {'id': 'MESH:D006632', 'name': 'Histamine'},
#     {'id': 'UBERON:0035501', 'name': 'Free nerve ending'},
#     {'id': 'GO:0070075', 'name': 'Tear secretion'},
#     {'id': 'MESH:D003233', 'name': 'Allergic conjunctivitis'}]}},
#  {'graph': {'_id': 'DB01284_MESH_D000309_1',
#    'nodes': [{'id': 'MESH:D003366', 'name': 'Tetracosactide'},
#     {'id': 'UniProtKB:Q01718', 'name': 'Adrenocorticotropic hormone receptor'},
#     {'id': 'REACT:R-HSA-170660',
#      'name': 'Adenylate cyclase activating pathway'},
#     {'id': 'GO:0006694', 'name': 'Steroid biosynthetic process'},
#     {'id': 'MESH:D000305', 'name': 'Adrenal Cortex Hormones'},
#     {'id': 'MESH:D000309', 'name': 'Adrenal cortical hypofunction'}]}},
#  {'graph': {'_id': 'DB04836_MESH_D003866_1',
#    'nodes': [{'id': 'MESH:C011597', 'name': 'Amineptine'},
#     {'id': 'UniProtKB:P23975',
#      'name': 'Sodium-dependent noradrenaline transporter'},
#     {'id': 'UniProtKB:Q01959',
#      'name': 'Sodium-dependent dopamine transporter'},
#     {'id': 'GO:0051620', 'name': 'Noradrenaline uptake'},
#     {'id': 'GO:0051583',
#      'name': 'Dopamine uptake involved in synaptic transmission'},
#     {'id': 'MESH:D009638', 'name': 'Noradrenaline'},
#     {'id': 'MESH:D004298', 'name': 'Dopamine'},
#     {'id': 'GO:0061533',
#      'name': 'Norepinephrine secretion, neurotransmission'},
#     {'id': 'GO:0061527', 'name': 'Dopamine secretion, neurotransmission'},
#     {'id': 'MESH:D003866', 'name': 'Depressive disorder'}]}},
#  {'graph': {'_id': 'DB04843_MESH_D010437_1',
#    'nodes': [{'id': 'MESH:C005101', 'name': 'Mepenzolate'},
#     {'id': 'UniProtKB:P20309', 'name': 'Muscarinic acetylcholine receptor M3'},
#     {'id': 'UniProtKB:P11229', 'name': 'Muscarinic acetylcholine receptor M1'},
#     {'id': 'GO:0001699',
#      'name': 'Acetylcholine-induced gastric acid secretion'},
#     {'id': 'MESH:D005744', 'name': 'Gastric acid'},
#     {'id': 'MESH:D010437', 'name': 'Peptic ulcer'}]}},
#  {'graph': {'_id': 'DB04843_MESH_D013276_1',
#    'nodes': [{'id': 'MESH:C005101', 'name': 'Mepenzolate'},
#     {'id': 'UniProtKB:P20309', 'name': 'Muscarinic acetylcholine receptor M3'},
#     {'id': 'UniProtKB:P11229', 'name': 'Muscarinic acetylcholine receptor M1'},
#     {'id': 'GO:0001699',
#      'name': 'Acetylcholine-induced gastric acid secretion'},
#     {'id': 'MESH:D005744', 'name': 'Gastric acid'},
#     {'id': 'MESH:D013276', 'name': 'Gastric ulcer'}]}},
#  {'graph': {'_id': 'DB04890_MESH_D003233_1',
#    'nodes': [{'id': 'DB:DB04890', 'name': 'Bepotastine'},
#     {'id': 'UniProtKB:P35367', 'name': 'Histamine H1 receptor'},
#     {'id': 'GO:0043303', 'name': 'Mast cell degranulation'},
#     {'id': 'MESH:D006632', 'name': 'Histamine'},
#     {'id': 'UBERON:0035501', 'name': 'Free nerve ending'},
#     {'id': 'GO:0070075', 'name': 'Tear secretion'},
#     {'id': 'MESH:D003233', 'name': 'Allergic conjunctivitis'}]}},
#  {'graph': {'_id': 'DB09122_MESH_D020529_1',
#    'nodes': [{'id': 'MESH:C428112', 'name': 'Peginterferon beta-1a'},
#     {'id': 'UniProtKB:P17181', 'name': 'Interferon alpha/beta receptor 1'},
#     {'id': 'GO:0006954', 'name': 'Inflammatory response'},
#     {'id': 'GO:0042100', 'name': 'B cell proliferation'},
#     {'id': 'GO:0050798', 'name': 'Activated T cell proliferation'},
#     {'id': 'GO:0019882', 'name': 'Antigen processing and presentation'},
#     {'id': 'MESH:D020529',
#      'name': 'Relapsing remitting multiple sclerosis'}]}},
#  {'graph': {'_id': 'DB09128_MESH_D003865_1',
#    'nodes': [{'id': 'MESH:C000591922', 'name': 'Brexpiprazole'},
#     {'id': 'UniProtKB:P08908', 'name': '5-hydroxytryptamine receptor 1A'},
#     {'id': 'UniProtKB:P14416', 'name': 'D(2) dopamine receptor'},
#     {'id': 'UniProtKB:P28223', 'name': '5-hydroxytryptamine receptor 2A'},
#     {'id': 'MESH:D012701', 'name': 'Serotonin'},
#     {'id': 'MESH:D004298', 'name': 'Dopamine'},
#     {'id': 'HP:0000716', 'name': 'Depressivity'},
#     {'id': 'GO:0060096', 'name': 'Serotonin secretion, neurotransmission'},
#     {'id': 'GO:0061527', 'name': 'Dopamine secretion, neurotransmission'},
#     {'id': 'MESH:D003865', 'name': 'Major depressive disorder'}]}},
#  {'graph': {'_id': 'DB09128_MESH_D012559_1',
#    'nodes': [{'id': 'MESH:C000591922', 'name': 'Brexpiprazole'},
#     {'id': 'UniProtKB:P08908', 'name': '5-hydroxytryptamine receptor 1A'},
#     {'id': 'UniProtKB:P14416', 'name': 'D(2) dopamine receptor'},
#     {'id': 'UniProtKB:P28223', 'name': '5-hydroxytryptamine receptor 2A'},
#     {'id': 'MESH:D012701', 'name': 'Serotonin'},
#     {'id': 'MESH:D004298', 'name': 'Dopamine'},
#     {'id': 'HP:0000716', 'name': 'Depressivity'},
#     {'id': 'GO:0060096', 'name': 'Serotonin secretion, neurotransmission'},
#     {'id': 'GO:0061527', 'name': 'Dopamine secretion, neurotransmission'},
#     {'id': 'MESH:D012559', 'name': 'Schizophrenia'}]}},
#  {'graph': {'_id': 'DB00060_MESH_D020529_1',
#    'nodes': [{'id': 'MESH:D000068556', 'name': 'Interferon beta-1a'},
#     {'id': 'UniProtKB:P17181', 'name': 'Interferon alpha/beta receptor 1'},
#     {'id': 'GO:0006954', 'name': 'Inflammatory response'},
#     {'id': 'GO:0042100', 'name': 'B cell proliferation'},
#     {'id': 'GO:0050798', 'name': 'Activated T cell proliferation'},
#     {'id': 'GO:0019882', 'name': 'Antigen processing and presentation'},
#     {'id': 'MESH:D020529',
#      'name': 'Relapsing remitting multiple sclerosis'}]}},
#  {'graph': {'_id': 'DB00162_MESH_D014802_1',
#    'nodes': [{'id': 'MESH:D014801', 'name': 'Retinol'},
#     {'id': 'GO:0016063', 'name': 'Rhodopsin biosynthetic process'},
#     {'id': 'GO:0042098', 'name': 'T cell proliferation'},
#     {'id': 'UniProtKB:P08100', 'name': 'Rhodopsin'},
#     {'id': 'GO:0002456', 'name': 'T cell mediated immunity'},
#     {'id': 'GO:0007603', 'name': 'Phototransduction, visible light'},
#     {'id': 'HP:0000662', 'name': 'Nyctalopia'},
#     {'id': 'MESH:D014802', 'name': 'Vitamin A deficiency'}]}},
#  {'graph': {'_id': 'DB00162_MESH_D001361_1',
#    'nodes': [{'id': 'MESH:D014801', 'name': 'Retinol'},
#     {'id': 'GO:0016063', 'name': 'Rhodopsin biosynthetic process'},
#     {'id': 'GO:0042098', 'name': 'T cell proliferation'},
#     {'id': 'UniProtKB:P08100', 'name': 'Rhodopsin'},
#     {'id': 'GO:0002456', 'name': 'T cell mediated immunity'},
#     {'id': 'GO:0007603', 'name': 'Phototransduction, visible light'},
#     {'id': 'HP:0000662', 'name': 'Nyctalopia'},
#     {'id': 'MESH:D001361', 'name': 'Vitamin deficiency'}]}},
#  {'graph': {'_id': 'DB00911_MESH_D008101_1',
#    'nodes': [{'id': 'MESH:D014011', 'name': 'Tinidazole'},
#     {'id': 'GO:0000305', 'name': 'Response to oxygen radical'},
#     {'id': 'MESH:D004247', 'name': 'DNA'},
#     {'id': 'taxonomy:5759', 'name': 'Entamoeba histolytica'},
#     {'id': 'MESH:D008101', 'name': 'Amebic liver abscess'}]}},
#  {'graph': {'_id': 'DB00911_MESH_D016585_1',
#    'nodes': [{'id': 'MESH:D014011', 'name': 'Tinidazole'},
#     {'id': 'GO:0000305', 'name': 'Response to oxygen radical'},
#     {'id': 'MESH:D004247', 'name': 'DNA'},
#     {'id': 'taxonomy:2', 'name': 'Bacteria'},
#     {'id': 'MESH:D016585', 'name': 'Bacterial vaginosis'}]}},
#  {'graph': {'_id': 'DB00911_MESH_D014245_1',
#    'nodes': [{'id': 'MESH:D014011', 'name': 'Tinidazole'},
#     {'id': 'GO:0000305', 'name': 'Response to oxygen radical'},
#     {'id': 'MESH:D004247', 'name': 'DNA'},
#     {'id': 'taxonomy:5722', 'name': 'Trichomonas vaginalis'},
#     {'id': 'MESH:D014245', 'name': 'Infection by Trichomonas'}]}},
#  {'graph': {'_id': 'DB00911_MESH_D005873_1',
#    'nodes': [{'id': 'MESH:D014011', 'name': 'Tinidazole'},
#     {'id': 'GO:0000305', 'name': 'Response to oxygen radical'},
#     {'id': 'MESH:D004247', 'name': 'DNA'},
#     {'id': 'taxonomy:5741', 'name': 'Giardia intestinalis'},
#     {'id': 'MESH:D005873', 'name': 'Giardiasis'}]}},
#  {'graph': {'_id': 'DB01117_MESH_D016778_1',
#    'nodes': [{'id': 'MESH:D053626', 'name': 'Atovaquone'},
#     {'id': 'UniProtKB:Q02768', 'name': 'Cytochrome b (Plasmodium falciparum)'},
#     {'id': 'UniProtKB:Q08210',
#      'name': 'Dihydroorotate dehydrogenase (quinone), mitochondrial'},
#     {'id': 'GO:0042773', 'name': 'ATP synthesis coupled electron transport'},
#     {'id': 'GO:0019856', 'name': 'Pyrimidine nucleobase biosynthetic process'},
#     {'id': 'taxonomy:5833', 'name': 'Plasmodium falciparum'},
#     {'id': 'MESH:D016778', 'name': 'Falciparum malaria'}]}},
#  {'graph': {'_id': 'DB01139_MESH_D004697_1',
#    'nodes': [{'id': 'MESH:D002514', 'name': 'Cefapirin'},
#     {'id': 'InterPro:IPR001460',
#      'name': 'Penicillin-binding protein, transpeptidase'},
#     {'id': 'GO:0018104', 'name': 'Cross-linking of the peptidoglycan'},
#     {'id': 'GO:0009273', 'name': 'Peptidoglycan-based cell wall biogenesis'},
#     {'id': 'GO:0005618', 'name': 'Cell wall'},
#     {'id': 'taxonomy:1280', 'name': 'Staphylococcus aureus'},
#     {'id': 'MESH:D004697', 'name': 'Bacterial endocarditis'}]}},
#  {'graph': {'_id': 'DB01139_MESH_D012226_1',
#    'nodes': [{'id': 'MESH:D002514', 'name': 'Cefapirin'},
#     {'id': 'InterPro:IPR001460',
#      'name': 'Penicillin-binding protein, transpeptidase'},
#     {'id': 'GO:0018104', 'name': 'Cross-linking of the peptidoglycan'},
#     {'id': 'GO:0009273', 'name': 'Peptidoglycan-based cell wall biogenesis'},
#     {'id': 'GO:0005618', 'name': 'Cell wall'},
#     {'id': 'taxonomy:39831',
#      'name': 'Klebsiella pneumoniae subsp. rhinoscleromatis'},
#     {'id': 'MESH:D012226', 'name': 'Rhinoscleroma'}]}},
#  {'graph': {'_id': 'DB01139_MESH_D004927_1',
#    'nodes': [{'id': 'MESH:D002514', 'name': 'Cefapirin'},
#     {'id': 'InterPro:IPR001460',
#      'name': 'Penicillin-binding protein, transpeptidase'},
#     {'id': 'GO:0018104', 'name': 'Cross-linking of the peptidoglycan'},
#     {'id': 'GO:0009273', 'name': 'Peptidoglycan-based cell wall biogenesis'},
#     {'id': 'GO:0005618', 'name': 'Cell wall'},
#     {'id': 'taxonomy:562', 'name': 'Escherichia coli'},
#     {'id': 'MESH:D004927', 'name': 'Infection due to Escherichia coli'}]}},
#  {'graph': {'_id': 'DB01139_MESH_D013203_1',
#    'nodes': [{'id': 'MESH:D002514', 'name': 'Cefapirin'},
#     {'id': 'InterPro:IPR001460',
#      'name': 'Penicillin-binding protein, transpeptidase'},
#     {'id': 'GO:0018104', 'name': 'Cross-linking of the peptidoglycan'},
#     {'id': 'GO:0009273', 'name': 'Peptidoglycan-based cell wall biogenesis'},
#     {'id': 'GO:0005618', 'name': 'Cell wall'},
#     {'id': 'taxonomy:1280', 'name': 'Staphylococcus aureus'},
#     {'id': 'MESH:D013203',
#      'name': 'Infection due to Staphylococcus aureus'}]}},
#  {'graph': {'_id': 'DB01139_MESH_D011023_1',
#    'nodes': [{'id': 'MESH:D002514', 'name': 'Cefapirin'},
#     {'id': 'InterPro:IPR001460',
#      'name': 'Penicillin-binding protein, transpeptidase'},
#     {'id': 'GO:0018104', 'name': 'Cross-linking of the peptidoglycan'},
#     {'id': 'GO:0009273', 'name': 'Peptidoglycan-based cell wall biogenesis'},
#     {'id': 'GO:0005618', 'name': 'Cell wall'},
#     {'id': 'taxonomy:1279', 'name': 'Staphylococcus'},
#     {'id': 'MESH:D011023', 'name': 'Staphylococcal pneumonia'}]}},
#  {'graph': {'_id': 'DB01139_MESH_D011014_1',
#    'nodes': [{'id': 'MESH:D002514', 'name': 'Cefapirin'},
#     {'id': 'InterPro:IPR001460',
#      'name': 'Penicillin-binding protein, transpeptidase'},
#     {'id': 'GO:0018104', 'name': 'Cross-linking of the peptidoglycan'},
#     {'id': 'GO:0009273', 'name': 'Peptidoglycan-based cell wall biogenesis'},
#     {'id': 'GO:0005618', 'name': 'Cell wall'},
#     {'id': 'taxonomy:2', 'name': 'Bacteria'},
#     {'id': 'MESH:D011014', 'name': 'Pneumonia'}]}},
#  {'graph': {'_id': 'DB01139_MESH_D011018_1',
#    'nodes': [{'id': 'MESH:D002514', 'name': 'Cefapirin'},
#     {'id': 'InterPro:IPR001460',
#      'name': 'Penicillin-binding protein, transpeptidase'},
#     {'id': 'GO:0018104', 'name': 'Cross-linking of the peptidoglycan'},
#     {'id': 'GO:0009273', 'name': 'Peptidoglycan-based cell wall biogenesis'},
#     {'id': 'GO:0005618', 'name': 'Cell wall'},
#     {'id': 'taxonomy:1313', 'name': 'Streptococcus pneumoniae'},
#     {'id': 'MESH:D011018', 'name': 'Pneumonia due to Streptococcus'}]}},
#  {'graph': {'_id': 'DB01139_MESH_D013290_1',
#    'nodes': [{'id': 'MESH:D002514', 'name': 'Cefapirin'},
#     {'id': 'InterPro:IPR001460',
#      'name': 'Penicillin-binding protein, transpeptidase'},
#     {'id': 'GO:0018104', 'name': 'Cross-linking of the peptidoglycan'},
#     {'id': 'GO:0009273', 'name': 'Peptidoglycan-based cell wall biogenesis'},
#     {'id': 'GO:0005618', 'name': 'Cell wall'},
#     {'id': 'taxonomy:1314', 'name': 'Streptococcus pyogenes'},
#     {'id': 'MESH:D013290', 'name': 'Streptococcus pyogenes infection'}]}},
#  ...]

# %%
# Save updated graph (node ID updated)
def save_graphs_to_yaml(graphs, filename):
    with open(filename, 'w') as file:
        yaml.dump(graphs, file)

save_graphs_to_yaml(graphs_converted, 'NodeID_updated_graphs.yaml')
